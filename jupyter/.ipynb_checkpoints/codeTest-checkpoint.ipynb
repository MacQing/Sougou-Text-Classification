# %% [markdown]
# ## 文本分类步骤
# - 划分数据集
# - 对标题和正文分词和去停用词
# - 计算tf-idf等特征
# - 构建分类器

# %% [markdown]
# ### 从ES取出带标签的数据，并dump到本地

# %%
import sys
sys.path.append('..')
import esProxy
from analyzer import Analyzer
import pickle

# 从ES导出带标签的新闻数据
sougouNews = esProxy.getDataFromEs()
print('成功导出新闻数据：size=%d' % (len(sougouNews)))

def featurelize(sougouNews, fields=['doc_title'], analyzer=Analyzer()):
    """
    返回标签和分词后的特征
    """
    tokens = []
    for doc in sougouNews:
        dic = {}
        for field in fields:
            dic[field] = analyzer.cutAndFilter(doc[field])
        # 添加新闻类别
        dic['doc_type'] = doc['doc_type']
        tokens.append(dic)
    return tokens

# 对新闻标题进行分词
tokenSougouNews = featurelize(sougouNews, fields=['doc_title'], analyzer=Analyzer())
print('完成对新闻标题的分词')
# 将分词后的结果dump到本地
filePathDump = 'tokenSougouNews.pk'
with open(filePathDump, 'wb') as f:
    f.truncate()
    pickle.dump(tokenSougouNews, f)
print('成功将分词后的数据dump到本地')
# Out:
# 成功导出新闻数据：size=103320
# 完成对新闻标题的分词
# 成功将分词后的数据dump到本地

# %%
tokenSougouNews
# Out:
# [{'doc_title': ['苹果', '在', '华频', '傍', '官司', 'Siri', '雪豹', '告', '被诉', '侵权']},
#  {'doc_title': ['iOS', '版谷歌', '地球', '7.0', '正式', '发布']},
#  {'doc_title': ['传',
#    '西班牙',
#    '电信',
#    '拟',
#    '出售',
#    '呼叫',
#    '中心',
#    '部门',
#    '套现',
#    '12',
#    '亿美元']},
#  {'doc_title': ['纽约时报', '已', '停止', '支持', '黑莓', '应用']},
#  {'doc_title': ['诺基亚', '6', '月', '份额', '不', '敌', '联想', '华为']},
#  {'doc_title': ['4', '用户', '目前', '还', '无法', '购买', 'Surface', '平板', '电脑']},
#  {'doc_title': ['H3C', '公司', 'CEO', '郑树生', '离职', '吴敬传', '接任']},
#  {'doc_title': ['联想', '成为', '第一', '大', 'PC', '商', '无忧', '利润率', '面临', '挑战']},
#  {'doc_title': ['传',
#    '微软',
#    'Surface',
#    '将',
#    '于',
#    '10',
#    '月',
#    '上市',
#    '最低',
#    '售价',
#    '6400',
#    '元']},
#  {'doc_title': ['周鸿祎', '怒斥', '小米', '威胁', '其', '家人', '雷军', '称', '法院', '见']},
#  {'doc_title': ['搜狐', '博客', '关注', '全球', '气候', '变暖']},
#  {'doc_title': ['新', 'iPhone', '网上', '曝光', '入手', '前', '看', '设计', '变化']},
#  {'doc_title': ['谷歌', '眼镜', '1500', '美元', '试水', '新', '商业模式']},
#  {'doc_title': ['艾瑞', '数据', '显示', '在线视频', '成为', '互联网', '第一', '大', '应用']},
#  {'doc_title': ['谷歌', '眼镜', '团队', '可', '穿戴', '电脑', '将会', '普及']},
#  {'doc_title': ['英国',
#    '一',
#    '女童',
#    '突发',
#    '脑溢血',
#    '昏迷',
#    '一周',
#    '被',
#    '母亲',
#    '歌声',
#    '唤醒']},
#  {'doc_title': ['腾讯', '的', '边界', '寻找', '企鹅', '的', '短板']},
#  {'doc_title': ['成飞', '集成', '拟', '涉足', '两', '万辆', '电动车', '租赁']},
#  {'doc_title': ['诺基亚', '折戟', '智能手机', '市场', '孰之错']},
#  {'doc_title': ['微软', 'Windows', 'Phone', '美国', '份额', '4%', '去年', '为', '3%']},
#  {'doc_title': ['诺基亚', 'Meego', '部门', '解散', '或', '即将', '放弃', '塞班']},
#  {'doc_title': ['微软', '发布', '首款', 'Android', '游戏', 'Kinectimals']},
#  {'doc_title': ['微软',
#    '对',
#    'PC',
#    '厂商',
#    '保密',
#    'Surface',
#    '计划',
#    '或',
#    '引发',
#    '业界',
#    '不满']},
#  {'doc_title': ['5',
#    '月',
#    '美国',
#    '视频',
#    '游戏',
#    '销售额',
#    '下跌',
#    '28%',
#    '至',
#    '5165',
#    '亿美元']},
#  {'doc_title': ['柳传志', '携', '30', '知名', '企业家', '赴', '英寻', '商机']},
#  {'doc_title': ['穿越', '神农架', '原始森林', '无人区', '大型', '科考', '本月', '启动']},
#  {'doc_title': ['Facebook',
#    '事件',
#    '致美',
#    'SEC',
#    '调查',
#    '纳斯达克',
#    '等',
#    '证券',
#    '交易所']},
#  {'doc_title': ['上海', '公交', '将', '搭载', 'WiFi', '系统', '技术设备', '已', '就绪']},
#  {'doc_title': ['微软',
#    '为',
#    'Windows',
#    'Azure',
#    '西欧',
#    '停运',
#    '2.5',
#    '小时',
#    '表示',
#    '道歉']},
#  {'doc_title': ['6', '月', '28', '日', '中国', '概念股', '航美', '传媒', '涨', '8.51%']},
#  {'doc_title': ['金山', '软件', '股份', '有限公司']},
#  {'doc_title': ['第十届', '网', '博会', '11', '月', '登陆', '北展', '规模', '超', '历届']},
#  {'doc_title': ['摄影',
#    '应用',
#    'Hipstamatic',
#    '推出',
#    'Snap',
#    '杂志',
#    '与',
#    '艺术',
#    '项目']},
#  {'doc_title': ['德国', '品牌', 'Dottling', '推出', '手表', '保险柜']},
#  {'doc_title': ['巧吹', '发型', '让', '睡', '变形', '的', '头发', '变', '蓬松']},
#  {'doc_title': ['从', '影视作品', '中看', '日本', '的', '忧患意识']},
#  {'doc_title': ['唐一菲', '婚后', '露面', '穿', '紧身衣', '否认', '怀孕']},
#  {'doc_title': ['女人', '会', '伪装', '床上', '的', '8', '个', '数据', '要', '知道']},
#  {'doc_title': ['2004', '05', '秋冬', '流行', '趋势', '爱登堡', '商务', '休闲装', '发布会']},
#  {'doc_title': ['顺美', '启动', '爱心', '之旅', '募', '十万', '善款', '慰问', '希望', '小学']},
#  {'doc_title': ['关于', '前女友', '的', '谎言', '贱', '男', '都', '会', '这么', '说']},
#  {'doc_title': ['夏日', '瘦身', '性感', '装扮', '黑色', '蕾丝', '不可', '少']},
#  {'doc_title': ['月经', '量少', '颜色', '黑', '教', '你', '中医', '调整', '秘方']},
#  {'doc_title': ['你', '觉得', '穿', '牛仔裤', '最', '好看', '的', '女星', '是', '谁']},
#  {'doc_title': ['评测', '结果']},
#  {'doc_title': ['中文名', '水合', '青春', '活能', '日霜', 'SPF10']},
#  {'doc_title': ['57', '岁', '罗大佑', '首次', '当爹', '女友', '未曾', '曝光']},
#  {'doc_title': ['智商', '测试', '女性', '近百年来', '首次', '超越', '男性']},
#  {'doc_title': ['口述', '闺蜜', '内急', '闯进', '我', '老公', '的', '浴室']},
#  {'doc_title': ['枯燥', '工作', '中', '她', '总能', '给', '我', '一抹', '亮色']},
#  {'doc_title': ['面相', '大', '占卜', '10', '牙齿']},
#  {'doc_title': ['我', '玩', '一夜情', '来', '报复', '老公', '的', '精神', '出轨']},
#  {'doc_title': ['经济型', '车', '对于', '每个', '购车人', '都', '不', '陌生', '...']},
#  {'doc_title': ['从', '头发', '特征', '看', '性格', '运势', '如何']},
#  {'doc_title': ['你会用', '化妆水', '吗', '错误方法', '毁脸']},
#  {'doc_title': ['校长', '骗', '12', '岁', '女生', '脱衣', '跳舞', '后', '强奸']},
#  {'doc_title': ['3', '分钟', '打造', '3D', '立体', '麻花', '辫', '刘海']},
#  {'doc_title': ['编辑', '点评']},
#  {'doc_title': ['09', '春夏', '流行色']},
#  {'doc_title': ['女生', '应该', '如何', '释放', '快乐', '荷尔蒙']},
#  {'doc_title': ['女人', '应该', '如何', '面对', '昔日', '的', '旧情', '人']},
#  {'doc_title': ['传递', '时尚', '沟通', '世界']},
#  {'doc_title': ['建', '在', '酒窖', '上', '的', '小镇', '探访', '香槟', '诞生地']},
#  {'doc_title': ['Office', '策略', '求职', '技巧', '人际关系', '处理']},
#  {'doc_title': ['刺猬', '测评', '夏季', '最', '温和', '润肤', '透气性', '不尽人意']},
#  {'doc_title': ['李冰冰', '姚晨', '孙俪', '五大', '女刊', '封面', '斗']},
#  {'doc_title': ['2010', '年', '10', '月', '11', '日', '第', '67', '期']},
#  {'doc_title': ['中国', '代表团', '伦敦', '奥运会', '礼服', '亮相']},
#  {'doc_title': ['爱情', '来', '敲门', '时', '的', '9', '大', '感觉', '让', '人', '陶醉']},
#  {'doc_title': ['我', '和', '丰满', '少妇', '在', '火车', '卧铺', '激情', '缠绵']},
#  {'doc_title': ['盛夏', '护发', '秘籍', '美丽', '要', '从', '发丝', '开始']},
#  {'doc_title': ['盘点', '历任', '夏季', '奥运会', '最高', '女', '祭司']},
#  {'doc_title': ['再次', '见面', '我', '糊涂', '献身', '花心', '钻石', '老公']},
#  {'doc_title': ['来自',
#    '全球',
#    '不同',
#    '国家',
#    '不同',
#    '肤色',
#    '不同',
#    '年龄',
#    '的',
#    '人',
#    '都',
#    '因为',
#    '一首',
#    'Nobody',
#    '被',
#    '联系',
#    '在',
#    '一起']},
#  {'doc_title': ['黄奕',
#    '优雅',
#    '亮相',
#    '时装',
#    '杂志',
#    '美妆节',
#    '称',
#    '美丽',
#    '需要',
#    '好',
#    '心态']},
#  {'doc_title': ['美丽', '帮帮忙', '卸妆油', '怎么', '用', '最', '有效']},
#  {'doc_title': ['炫富', '美女', '微博晒', '熊掌', '惹怒', '网友', '遭', '声讨']},
#  {'doc_title': ['搜狐', '女人', '频道', '生活', '新', '栏目']},
#  {'doc_title': ['宝马', '女', '酒后', '砸', '饭店', '交警', '爹欲', '打', '民警']},
#  {'doc_title': ['女性', '媒体', '话题', '编辑', '女性', '学', '学者', '情感', '专家']},
#  {'doc_title': ['一年',
#    '时间',
#    '做',
#    '的',
#    '心理',
#    '建设',
#    '在',
#    '这个',
#    '爱情',
#    '泛滥',
#    '的',
#    '日子',
#    '又',
#    '崩塌',
#    '了']},
#  {'doc_title': ['奥运',
#    '同',
#    '参与',
#    '鲜花',
#    '传',
#    '友谊',
#    '之',
#    '奥运',
#    '鲜花',
#    '友谊',
#    '架',
#    '是',
#    '整个',
#    '鲜花',
#    '活动',
#    '的']},
#  {'doc_title': ['邓超', '周渝民', '彭于', '晏', '帅哥', '扎堆', '看秀']},
#  {'doc_title': ['高考', '现', '最', '霸气', '名字', '是', '朕', '确有其人']},
#  {'doc_title': ['1944', '年', '8', '月', '生于', '米兰']},
#  {'doc_title': ['婆婆', '以', '老公', '体弱', '为', '由', '让', '我们', '少爱爱']},
#  {'doc_title': ['Edition',
#    '10',
#    '系列',
#    '重新',
#    '诠释',
#    '高级',
#    '时装',
#    '的',
#    '穿着',
#    '概念']},
#  {'doc_title': ['艺术', '新闻', '评出', '2012', '年', '全球', '十大', '藏家']},
#  {'doc_title': ['白色', '羊皮夹克', 'EQ', 'IQ4500', '元']},
#  {'doc_title': ['美女', '营销', '基金', '非', '特例', '金融业', '内', '潜规则']},
#  {'doc_title': ['美体', '研究院', '7', '种', '黑色', '食物', '补肾', '美颜']},
#  {'doc_title': ['清爽', '条纹', '衫', '减龄', '显著', '打造', '花样', '美男']},
#  {'doc_title': ['护肤', '防老', '保养', '经', '偷学', '明星', '减龄术']},
#  {'doc_title': ['广东',
#    '高院',
#    '延迟',
#    '商标',
#    '案',
#    '宣判',
#    '新',
#    'iPad',
#    '内地',
#    '上市',
#    '恐',
#    '延后']},
#  {'doc_title': ['咬口', '苹果', '难填', '债务', '窟窿', '唯冠', '拒付', '律师费', '被', '起诉']},
#  {'doc_title': ['魔兽', '世界', '熊猫', '人', '之谜', '配置', '要求', '或', '略有', '提升']},
#  {'doc_title': ['长江', '江豚', '种群', '面临', '灭绝', '危险', '亟待', '保护']},
#  {'doc_title': ['华硕', '推出', '双高清', '触屏', '超极本', '成本', '或超', '900', '美元']},
#  {'doc_title': ['军队',
#    '女',
#    '少校',
#    '梦中',
#    '找到',
#    '编程',
#    '灵感',
#    '写',
#    '完',
#    '昏迷',
#    '3',
#    '天']},
#  {'doc_title': ['全球', '最富', '互联网', '企业家', '排行榜', '亚马逊', 'CEO', '排', '第一']},
#  {'doc_title': ['雅虎', 'Facebook', '正在', '和解', '谈判', '要', '法官', '推迟', '审案']},
#  {'doc_title': ['Google', '眼镜', '终于', '正式', '现身']},
#  {'doc_title': ['德国', '研制', '出', '世界', '首款', '化学', '芯片']},
#  {'doc_title': ['6', '月', '26', '日', '天宇', '将', '上演', '火星', '合月', '天象']},
#  {'doc_title': ['联想', '交接班', '朱立', '南接', '帅印', '联想', '之星搏', '未来']},
#  {'doc_title': ['传', 'UCWeb', '与', '百度', '就', '合作', '事宜', '进行', '初步', '谈判']},
#  {'doc_title': ['宽带', '中国', '战略', '谜底', '一纸', '战略', '能否', '解决', '多方', '诉求']},
#  {'doc_title': ['评论', '苹果', '手机', '别', '拿', '霸气', '赌', '明天']},
#  {'doc_title': ['中国', '天链', '一号', '中继', '卫星', '全球', '组网', '全轨', '覆盖']},
#  {'doc_title': ['新浪', '微博双', '平台', '之梦']},
#  {'doc_title': ['360',
#    '特供',
#    '机',
#    'AK47',
#    '将',
#    '于',
#    '6',
#    '月',
#    '28',
#    '日',
#    '开放',
#    '购买',
#    '定价',
#    '1699',
#    '元']},
#  {'doc_title': ['谷歌',
#    '将',
#    '在',
#    '英售',
#    'Android',
#    '智能',
#    '电视',
#    '200',
#    '英镑',
#    '起售']},
#  {'doc_title': ['索尼', '力挺', 'Google', 'TV', '199', '美元', '机顶盒', '发布']},
#  {'doc_title': ['八成', '网站', '登录', '密码', '存', '漏洞', '网络', '电商', '成', '重灾区']},
#  {'doc_title': ['拉', '卡拉', '手机', '刷卡器', '涉嫌', '暴利']},
#  {'doc_title': ['澳大利亚',
#    '19',
#    '名',
#    '数学家',
#    '组团',
#    '赌博',
#    '3',
#    '年',
#    '狂',
#    '赢',
#    '156',
#    '亿']},
#  {'doc_title': ['2012', '移动', '互联网', '创新', '大会', '雷军', '王', '小川', '等', '出席']},
#  {'doc_title': ['欧洲杯', '伪', '球迷', '装逼', '指南']},
#  {'doc_title': ['著作权法', '修改草案', '二稿', '删除', '网络盗版', '争议', '内容']},
#  {'doc_title': ['增加', '电影', '和', '图书', '分享', '功能', 'Path', '更加', '注重', '互动']},
#  {'doc_title': ['图文', '中国', '男排', '无缘', '伦敦', '奥运', '梁春龙', '比赛', '中', '扣球']},
#  {'doc_title': ['WTO',
#    '判',
#    '银联',
#    '歧视',
#    'VISA',
#    '外资',
#    '猛',
#    '敲',
#    '中国',
#    '电子',
#    '支付',
#    '大门']},
#  {'doc_title': ['中',
#    '移动',
#    '香港',
#    '招标',
#    '上马',
#    '4G',
#    '牌照',
#    '发放',
#    '很',
#    '有',
#    '可能',
#    '提前']},
#  {'doc_title': ['新', 'Air', '频繁', '崩溃', '与', 'Chrome', '有关']},
#  {'doc_title': ['互联网', '撞机', '玩票', '居多', '终端', '市场', '半年', '后', '洗牌']},
#  {'doc_title': ['当当网', '被', '曝', '出售', '假', '卡西欧', '表']},
#  {'doc_title': ['新浪', '微博', '推', '普通用户', '版微博', '置顶', '功能', '需', '开通', '会员']},
#  {'doc_title': ['中国电信', '与', '华谊', '跨界', '合作']},
#  {'doc_title': ['手机', '上网', '不用', '盲', '手机', '冲浪', '帮', '您', '忙']},
#  {'doc_title': ['女孩',
#    '发动',
#    '反',
#    'PS',
#    '圣战',
#    '杂志',
#    '被迫',
#    '签订',
#    '不',
#    'P',
#    '脸',
#    '和约']},
#  {'doc_title': ['罗永浩', '做', '手机', '山寨', '班底', '和', '忽然', '而', '至', '的', '转机']},
#  {'doc_title': ['银行卡', '复制器', '网上', '公开', '出售', '最低', '8000', '元', '一套']},
#  {'doc_title': ['知名', 'VC', '霍洛', '维茨', '的', '个人爱好', '起床', '先看', 'Twitter']},
#  {'doc_title': ['去', '哪儿', '网', '推出', '手机', '版', '酒店', '独立', '客户端']},
#  {'doc_title': ['手机', '卖家', '搭', '上', '电子商务', '快车道']},
#  {'doc_title': ['拆解',
#    '研究',
#    '显示',
#    'Google',
#    '亏本',
#    '销售',
#    '8GB',
#    '版',
#    'Nexus',
#    '7']},
#  {'doc_title': ['Google', '收购', '办公', '程序', '开发商', 'Quickoffice']},
#  {'doc_title': ['她', '约', '我', '出来', '只为', '让', '我', '帮', '她', '破', '处女膜']},
#  {'doc_title': ['心细', '老公', '那些', '让', '人', '难以忍受', '的', '烦恼']},
#  {'doc_title': ['这是', '当前', '社会', '审丑', '的', '一种', '趋势']},
#  {'doc_title': ['今夏', '斜肩', '连衣裙', '最', 'IN', '穿', '出', '女神', '气质']},
#  {'doc_title': ['八卦', '明星脸', '章子怡', '素肌', '出口', '转', '内销']},
#  {'doc_title': ['偷学', '情场', '高手', '的', '无敌', '约会', '秘籍']},
#  {'doc_title': ['雅诗兰黛', '臻', '致亮', '颜', '粉底液']},
#  {'doc_title': ['成龙', '回应', '儿子', '恋情', '趁', '年轻', '多', '找', '女孩']},
#  {'doc_title': ['一双',
#    '瘦腿量',
#    '地球',
#    '甘苦',
#    '全埋',
#    '心里',
#    '头',
#    '若遇',
#    '蓝颜亲',
#    '芳泽',
#    '只触',
#    '骨皮',
#    '不见',
#    '肉']},
#  {'doc_title': ['男人', '20', '嫩', '30', '奸', '只有', '40', '熟', '男', '最宜', '嫁']},
#  {'doc_title': ['传递', '时尚', '沟通', '世界']},
#  {'doc_title': ['孙俪', '透视', '秀美', '腿', '张梓琳', '女神', '玩虐', '胸']},
#  {'doc_title': ['您', '期待', '未来', '的', '女人', '视线', '长成', '什么', '样子']},
#  {'doc_title': ['我们', '想象', '中', '的', '全职', '主妇']},
#  {'doc_title': ['女性', '犯罪', '多因', '家庭暴力']},
#  {'doc_title': ['gaga', '伞裙', '淡定', '回归', '群星', '劲', '刮', '橙色', '风']},
#  {'doc_title': ['露出', '锁骨', '的', '大', '圆领', '印花', '裙', '加宽', '腰带', '最']},
#  {'doc_title': ['两性', '揭秘', '与', '爱', '爱', '有关', '的', '趣味', '数字']},
#  {'doc_title': ['我妈',
#    '说生',
#    '我',
#    '的',
#    '时候',
#    '想不出',
#    '啥',
#    '名字',
#    '忽然',
#    '听到',
#    '窗外',
#    '有',
#    '谁家',
#    '的',
#    '风铃',
#    '在',
#    '响',
#    '于是',
#    '取为',
#    '丁当']},
#  {'doc_title': ['喜欢',
#    '吊带装',
#    '的',
#    '女孩子',
#    '们',
#    '很',
#    '想',
#    '循',
#    '着',
#    '吊带',
#    '衣',
#    '的',
#    '芳踪',
#    '从',
#    '夏天',
#    '走',
#    '到',
#    '金秋',
#    '吧']},
#  {'doc_title': ['章子怡', '秘恋', '撒', '贝宁', '地下', '情', '逼死', '有情人']},
#  {'doc_title': ['八卦', '明星脸', '杨钰莹', '发福', '小腹', '隆起']},
#  {'doc_title': ['短裤', 'vs', '长裤', '看潮', '人', '如何', '时髦', '秀美', '腿']},
#  {'doc_title': ['作为',
#    '中国',
#    '的',
#    '本土',
#    '设计师',
#    '在',
#    '世界',
#    '时尚',
#    '舞台',
#    '的',
#    '成功',
#    '代表']},
#  {'doc_title': ['下午茶', '的', '配点']},
#  {'doc_title': ['女人',
#    '别',
#    '指望',
#    '男人',
#    '会',
#    '帮',
#    '你',
#    '做',
#    '的',
#    '7',
#    '件',
#    '事']},
#  {'doc_title': ['洞房', '夜', '老公', '让', '我', '模仿', '他', '前妻', '的', '姿势']},
#  {'doc_title': ['际', '通宝', '助', '企业', '掌握', '电子商务', '主动权']},
#  {'doc_title': ['苹果', '地图', '迎战', '谷歌', '谷歌', '一下', '变', '问问', 'Siri']},
#  {'doc_title': ['评论', '如今', '的', '谷歌', '是', '一家', '硬件', '公司', '吗']},
#  {'doc_title': ['不想', '亲自动手', '服务', '外包', 'Sooqini', '找人', '帮', '你', '搞定']},
#  {'doc_title': ['国际版', 'Sony', 'Xperia', 'LT29i', '谍', '照曝光']},
#  {'doc_title': ['Kindle', 'Fire', '2', '八月', '降临', '保留', '8.9', '寸版']},
#  {'doc_title': ['摘自',
#    '美国',
#    '科学',
#    '杂志',
#    '网络版',
#    '关于',
#    '美国',
#    '北卡罗',
#    '莱',
#    '纳州',
#    '杜克大学',
#    '的',
#    '研究',
#    '报道']},
#  {'doc_title': ['坐飞机', '时', '手机', '能否', '开', '飞行', '模式']},
#  {'doc_title': ['HTC', '推', '中低端', 'Desire', '系列', '新机']},
#  {'doc_title': ['新', 'iPad', '或于', '本月底', '开卖']},
#  {'doc_title': ['电商',
#    '仓库',
#    '多',
#    '藏身',
#    '城乡',
#    '接合部',
#    '包装工',
#    '每件',
#    '挣',
#    '1',
#    '元']},
#  {'doc_title': ['军事', '网游', '十年', '厚积薄发', '十余', '款', '作品', '决战', '2012']},
#  {'doc_title': ['苹果', '调整', 'AppStore', '应用', '搜索', '排序', '算法']},
#  {'doc_title': ['专家',
#    '新',
#    '顶级',
#    '域名',
#    '不会',
#    '导致',
#    '互联网',
#    '企业',
#    '竞争',
#    '再',
#    '升级']},
#  {'doc_title': ['千元', '手机', '进入', '高速', '增长期']},
#  {'doc_title': ['诺基亚', '中国区', '裁员', '计划', '细节', '今日', '公布']},
#  {'doc_title': ['专家', '指甲油', '含', '杀死', '胰岛', '细胞', '成分', '或致', '糖尿病']},
#  {'doc_title': ['iPhone', '霸主', '地位', '渐失', '苹果', '大中华区', '业绩', '环比', '大跌']},
#  {'doc_title': ['PayPal', '与', '起点', '中文网', '合作']},
#  {'doc_title': ['联想集团', '高级', '副', '总裁兼', 'idea', '产品', '集团', '总裁', '刘军']},
#  {'doc_title': ['移动',
#    '公司',
#    '出售',
#    '用户',
#    '信息',
#    '1',
#    '分钟',
#    '发',
#    '1.5',
#    '万条',
#    '垃圾',
#    '短信']},
#  {'doc_title': ['Nexus', 'Q', '小球', '赏析', 'Android', '设备', '遥控器', '组图']},
#  {'doc_title': ['美银', '美林', '将', '完美', '世界', '股票', '评级', '为', '买入']},
#  {'doc_title': ['LinkedIn', '证实', '部分', '会员', '密码', '遭窃', '数量', '未', '公布']},
#  {'doc_title': ['图文', '雅典奥运', '回顾', '跆拳道', '陈中', '脚踢', '对手']},
#  {'doc_title': ['1', '如果', '你', '身边', '有人', '感染', '了', '爱滋病', '您', '会']},
#  {'doc_title': ['Alexander', 'McQueen', '秀场']},
#  {'doc_title': ['评论',
#    'Surface',
#    '望',
#    '打破',
#    'Windows',
#    '系统',
#    '平板',
#    '电脑',
#    '僵局']},
#  {'doc_title': ['全新', '娇韵诗', '双萃', '赋活', '修护', '精华', '露', '10', '月', '上市']},
#  {'doc_title': ['新知', '做爱', '一年', '耗热', '慢跑', '90', '公里']},
#  {'doc_title': ['曝撒', '贝宁', '旧爱', '经纬', '恋情', '携', '新欢', '回家']},
#  {'doc_title': ['质疑', '90', '年代', '生人', '的', '文化', '传承']},
#  {'doc_title': ['12', '星座', '中', '谁', '最', '不顾', '别人', '感受']},
#  {'doc_title': ['内在', '调养', '养出', '肌肤', '好', '气色']},
#  {'doc_title': ['高考', '开始', '师弟', '师妹', '喊楼', '送祝福']},
#  {'doc_title': ['你', '到底', '多显', '老', '外貌', '计算器', '帮', '你', '算']},
#  {'doc_title': ['网友', '下', '黄片', '被', '拘', '15', '天', '罚款', '3000']},
#  {'doc_title': ['口述', '男友', '把', '套套', '藏进', '闺蜜', '的', '文胸']},
#  {'doc_title': ['亚洲', '彩妆', '界', '殿堂', '级', '人物', 'Andy', '老师']},
#  {'doc_title': ['苹果', '对', '近场', '通信', '的', '野心', '不仅仅', '是', '移动', '支付']},
#  {'doc_title': ['天霆云', '电脑', '颠覆', '传统', 'IT', '模式']},
#  {'doc_title': ['激动',
#    '网',
#    '声明',
#    '北京',
#    '业务',
#    '略有',
#    '调整',
#    '不',
#    '存在',
#    '解散',
#    '一说']},
#  {'doc_title': ['夏普', '低迷', '郭台铭', '着急', '盼', '加入', '董事会', '推进改革']},
#  {'doc_title': ['节前', '示爱', '小花招', '轻松', '搞定', '女人', '心']},
#  {'doc_title': ['李湘', '红色', '蕾丝', '贵妇', '装', '透视', '圆润', '身材']},
#  {'doc_title': ['奈瑞儿', '保鲜', '肌肤', '锁住', '美丽', '青春']},
#  {'doc_title': ['呼拉圈',
#    '要',
#    '选择',
#    '摇起来',
#    '撞击',
#    '腰部',
#    '像',
#    '在',
#    '轻轻',
#    '按摩',
#    '的',
#    '最好',
#    '而且',
#    '摇',
#    '的',
#    '时候',
#    '要',
#    '将',
#    '手举',
#    '高',
#    '收紧',
#    '小腹']},
#  {'doc_title': ['LV', '为', '与', 'Yayoi', 'Kusama', '开设', '临时', '店']},
#  {'doc_title': ['梅根', '福克斯', '走', 'OL', '路线']},
#  {'doc_title': ['3',
#    '年前',
#    '因为',
#    '一场',
#    '车祸',
#    '她',
#    '离开',
#    '了',
#    '这个',
#    '世界',
#    '而',
#    '我',
#    '的',
#    '幸福生活',
#    '打上',
#    '了',
#    '句号']},
#  {'doc_title': ['夫妻', '不', '和', '杀子', '泄愤', '毒妈', '被', '判刑', '8', '年']},
#  {'doc_title': ['车缝', '品牌', '标志']},
#  {'doc_title': ['网通',
#    '成',
#    '电讯',
#    '盈科',
#    '的',
#    '战略',
#    '投资者',
#    '和',
#    '第二',
#    '大',
#    '股东']},
#  {'doc_title': ['妻子', '为', '还', '情债', '上', '上司', '床']},
#  {'doc_title': ['1996', '年', '女篮', '亚洲', '锦标赛', '冠军']},
#  {'doc_title': ['外媒称', '诺基亚', '裁员', '得罪', '人', '埃洛普', '被', '贴身', '保护']},
#  {'doc_title': ['孙雅君', '做客', '搜狐', '畅谈', '健康', '新时尚']},
#  {'doc_title': ['和谐', '融汇', '的', '花香', '好似', '晨间', '露珠', '的', '空灵', '晶莹']},
#  {'doc_title': ['外国', '名模', '戴文', '青木']},
#  {'doc_title': ['婚后', '老公', '得知', '我装', '处女', '硬要', '退货']},
#  {'doc_title': ['徕', '卡', '爱马仕', '合作', '款', '正式', '开始', '售卖']},
#  {'doc_title': ['条子', '战衣', '抢眼', '新元素']},
#  {'doc_title': ['毕业', '再', '出新招', '高校', '男生', '内裤', '跑']},
#  {'doc_title': ['好女', '不愁', '嫁', '缘分', '未来', '到', '剩下', '又', '何妨']},
#  {'doc_title': ['性生活', '也', '有', '失业', '的', '时候']},
#  {'doc_title': ['女', '学生', '被', '错关', '9', '个', '月', '警方', '称', '因假', '口供']},
#  {'doc_title': ['手机',
#    '业',
#    '全球',
#    '巨头',
#    '纷陷',
#    '漩涡',
#    '亏损',
#    '加',
#    '裁员',
#    '日子',
#    '难过']},
#  {'doc_title': ['嘉宾', '对', '从事', '行业', '的', '理解', '和', '看法']},
#  {'doc_title': ['夏朗', '超长', '待机', '3G', '智能手机', '上市']},
#  {'doc_title': ['天体', '物理学家', '发现', '了', '奇特', '的', '长方形', '星系']},
#  {'doc_title': ['Instagram', '宣布', '用户', '超过', '8000', '万', '大关']},
#  {'doc_title': ['男友',
#    '被',
#    '我',
#    '甩',
#    '了',
#    '17',
#    '次',
#    '却',
#    '还',
#    '坚持',
#    '不',
#    '放弃']},
#  {'doc_title': ['陈年',
#    '斥',
#    '电商',
#    '平台',
#    '战',
#    '很',
#    '下作',
#    '称',
#    '电商',
#    '依然',
#    '有',
#    '泡沫']},
#  {'doc_title': ['那',
#    '这些',
#    '方式',
#    '中',
#    '哪',
#    '一种',
#    '最能',
#    '打动',
#    '女人',
#    '的',
#    '心',
#    '呢']},
#  {'doc_title': ['男人', '更能', '记住', '女人', '凶悍', '后', '的', '温柔']},
#  {'doc_title': ['84', '岁', '离休干部', '变性', '呼吁', '远离', '偏见']},
#  {'doc_title': ['时尚', '影响力', '搜狐', '女人', '小S', '专访']},
#  {'doc_title': ['神秘', '狂野', '北领地', '自然', '之旅', '的', '天堂']},
#  {'doc_title': ['细格', '套装', '尽显', '你', '的', '温文尔雅', '图']},
#  {'doc_title': ['2011', '年', '01', '月', '24', '日', '第', '78', '期']},
#  {'doc_title': ['刺猬', '测评', '国货', '补水', '精品', '水嫩', '饱满']},
#  {'doc_title': ['甜言蜜语', '对', '左耳', '说', '有效', '右耳', '更', '听', '劝']},
#  {'doc_title': ['简单', '4', '步', '瞬间', '画出', '欧美', '立体', '美鼻妆']},
#  {'doc_title': ['婚前', '恐惧症', '阻挡', '了', '笨', '女人', '的', '幸福', '路']},
#  {'doc_title': ['宇航员', '太空', '性生活', '事关', '火星', '之旅', '成败']},
#  {'doc_title': ['奥迪', '女召', '警察', '打人', '涉事', '所长', '被', '免职']},
#  {'doc_title': ['老公', '天天', '都', '要', '爱', '爱', '害', '我', '伤痕累累']},
#  {'doc_title': ['4',
#    '小女孩',
#    '用',
#    '吸烟',
#    '夜游',
#    '多交',
#    '男友',
#    '表示',
#    '成熟',
#    '你',
#    '就',
#    '不必',
#    '了',
#    '随缘',
#    '但',
#    '不是',
#    '说',
#    '不',
#    '努力']},
#  {'doc_title': ['香港', '设计师', '讲', '手机', '与', '时装', '搭配']},
#  {'doc_title': ['世界', '瑜伽', '冠军', '莫慧萍']},
#  {'doc_title': ['美国', '男子', '与', '17', '名', '女子', '共生', '23', '个', '小孩']},
#  {'doc_title': ['用', '九个', '动作', '增添', '女人', '性感', '与', '魅力']},
#  {'doc_title': ['三星', '巨屏', '手机', 'Galaxy', 'Note', '2', '再', '曝光']},
#  {'doc_title': ['超模', '出演', '伦敦', '奥运', '闭幕', '收费', '1', '英镑']},
#  {'doc_title': ['视频', '那些', '年', '我们', '一起', '坚守', '的', '岁月']},
#  {'doc_title': ['搜狐', '女人', '频道', '生活', '新', '栏目']},
#  {'doc_title': ['做不了', '情人', '做', '朋友']},
#  {'doc_title': ['关于', '接吻', '这件', '小事']},
#  {'doc_title': ['女星', '红毯', '秘笈', '挤', '胸露', '腿', '不如', '女神', '范儿']},
#  {'doc_title': ['无法自拔', '的', '爱', '上', '了', '大', '我', '36', '岁', '的', '上司']},
#  {'doc_title': ['温柔', '的', '洋', '老公', '帮', '我', '克服', '了', '性冷淡']},
#  {'doc_title': ['保养', '秘诀', '不', '使用', '过于', '滋润', '产品', '有', '针对性', '护肤']},
#  {'doc_title': ['英', '30', '岁', '下', '艺人', '富豪榜', '哈利波', '特', '登顶']},
#  {'doc_title': ['独身', '但', '依然', '和', '情人', '约会']},
#  {'doc_title': ['收腰', 'A', '字', '连衣裙', '夏天', '女生', '线条', '法宝']},
#  {'doc_title': ['本', '宫', '挚友', '杨冠华', '的', '古着', '秀']},
#  {'doc_title': ['活跃', '在', '欧洲', '艺术', '市场', '的', '收藏家', '圈子']},
#  {'doc_title': ['Peter', 'Marino']},
#  {'doc_title': ['这',
#    '一天',
#    '我',
#    '不能',
#    '在',
#    '您',
#    '身边',
#    '为',
#    '您',
#    '过节',
#    '但是',
#    '我会',
#    '在',
#    '心底',
#    '深深',
#    '祝福',
#    '您']},
#  {'doc_title': ['美丽', '帮帮忙', 'SPF', '食物', '提升', '肌肤', '防晒', '力']},
#  {'doc_title': ['张嘉倪', '出席', '时装', '杂志', '美妆节', '沙龙', '现场', '改妆']},
#  {'doc_title': ['河南', '一', '女生', '因', '高考', '成绩', '不好', '跳河自杀']},
#  {'doc_title': ['媳妇', '规定', '好', '婆婆', '标准', '网友', '褒贬不一']},
#  {'doc_title': ['浙大', '校长', '疑似', '开会', '玩牌', '引发', '争议']},
#  {'doc_title': ['3.15', '不让', '我', '的', '美丽', '受伤']},
#  {'doc_title': ['孙俪', '小S', '同穿', '白裙', '时尚', '辣妈', '硬碰硬']},
#  {'doc_title': ['埃及', '面纱', '女性频道', '开播', '只露', '眼睛']},
#  {'doc_title': ['联想',
#    '称',
#    'Win',
#    '8',
#    '与',
#    '降价',
#    '结合',
#    '将',
#    '加速',
#    '超极本',
#    '销售',
#    '增长']},
#  {'doc_title': ['香格里拉', '世人', '寻觅', '已久', '的', '人间仙境']},
#  {'doc_title': ['老公', '不', '负责', '女人', '给', '我', '过来']},
#  {'doc_title': ['关键词', '硬朗', '风', '金属光泽', '亮色']},
#  {'doc_title': ['老公',
#    '慌忙',
#    '的',
#    '端',
#    '出',
#    '饭菜',
#    '我大口',
#    '大口',
#    '的',
#    '吃',
#    '着',
#    '饭菜',
#    '夹',
#    '和',
#    '着',
#    '泪水',
#    '一起',
#    '吃',
#    '了',
#    '下去',
#    '......']},
#  {'doc_title': ['千年', '古寺', '方丈', '还俗', '迎娶', '26', '岁', '女老板']},
#  {'doc_title': ['沈阳',
#    '成',
#    'TD',
#    'LTE',
#    '扩大',
#    '规模',
#    '试验',
#    '城市',
#    '明年',
#    '建',
#    '千余',
#    '基站']},
#  {'doc_title': ['武平',
#    '表示',
#    '未来',
#    '外国',
#    '航天员',
#    '会',
#    '乘',
#    '神舟',
#    '飞船',
#    '飞',
#    '向太空']},
#  {'doc_title': ['哪个', '星座', '最', '值得', '你', '去', '爱']},
#  {'doc_title': ['惊艳', '印花', '雪纺裙', '灵动', '飘逸', '显白', '显嫩']},
#  {'doc_title': ['镂空', '鞋令', '你', '足底', '也', '风光', '图']},
#  {'doc_title': ['雄浑', '典雅', '卡地亚', '全新', 'Tank', '腕表']},
#  {'doc_title': ['曝邱', '启明', '签约', '芒果', '台', '央视', '暧昧', '回应']},
#  {'doc_title': ['Surface',
#    '触摸',
#    '键盘',
#    '的',
#    '售价',
#    '在',
#    '60',
#    '100',
#    '美元',
#    '之间']},
#  {'doc_title': ['恋爱', '八年', '没', '结婚', '男友', '竟成', '啃老族']},
#  {'doc_title': ['英国', '无敌', '海景', '豪宅', '售价', '千万英镑']},
#  {'doc_title': ['从', '女人', '体型', '看其', '床上', '功夫', '如何']},
#  {'doc_title': ['上衣', '搭配', '膝上', '短裤', '利落', '帅气', '秀美', '腿']},
#  {'doc_title': ['昔日', '手机', '霸主', '光环', '褪尽', '诺基亚', '拿', '什么', '自我', '拯救']},
#  {'doc_title': ['英国',
#    '皇室',
#    '崛起',
#    '于',
#    '西元',
#    '三',
#    '世纪',
#    '左右',
#    '是',
#    '目前',
#    '现存',
#    '最',
#    '古老',
#    '的',
#    '王族',
#    '而且',
#    '每代君']},
#  {'doc_title': ['相亲',
#    '节目',
#    '来源于',
#    '剩女',
#    '现实',
#    '消费',
#    '了',
#    '剩女',
#    '恐慌',
#    '忽略',
#    '了',
#    '剩女',
#    '心理']},
#  {'doc_title': ['两性', '男人', '想要', '婚前', '性', '的', '7', '大', '原因']},
#  {'doc_title': ['21', '期']},
#  {'doc_title': ['联想', '乐', 'Phone', 'S880', '上演', '大', '有意思', '登船', '记']},
#  {'doc_title': ['光场', '相机', 'Lytro', '推', 'Windows', '桌面', '软件']},
#  {'doc_title': ['诺基亚', '中国', '合并', '为', '南北', '两', '大区', '将', '裁减人员']},
#  {'doc_title': ['我国', '电话', '用户', '达', '13.2', '亿户']},
#  {'doc_title': ['李鬼', '返利', '网站', '涉嫌', '传销', '被查']},
#  {'doc_title': ['国产手机', '加入', '安卓', '4.0', '竞争']},
#  {'doc_title': ['凡客', '牵手', '小米', '试水', '3C', '图书', '是', '下', '一', '目标']},
#  {'doc_title': ['政府', '微博频', '更新', '雨情', '信息', '市民', '刷屏', '知', '汛情']},
#  {'doc_title': ['华尔街日报', '联想', '通过', '自主', '生产', '加速', '创新']},
#  {'doc_title': ['专访', '中国电信', '王晓初', 'CDMA', '产业链', '一年', '比', '一年', '好']},
#  {'doc_title': ['正点', '闹钟', 'CEO', '王颖奇']},
#  {'doc_title': ['联通', '随意', '打', '正式', '登陆', '重庆', '网', '内', '拨打', '全免费']},
#  {'doc_title': ['雅虎公司', '宣布', '任命', '新', 'CEO']},
#  {'doc_title': ['三星', '手机', '成功', '背后', '抢', '市场', '空白', '重', '本地化']},
#  {'doc_title': ['极致', '典雅', '简约', 'Duck', 'Image', '竹制', '桌灯']},
#  {'doc_title': ['微软', '宣布', '完成', '对', '企业', '社交', '网', 'Yammer', '收购']},
#  {'doc_title': ['惊人', '初次', '性爱', '不要', '晚于', '23', '岁']},
#  {'doc_title': ['今夏', '斜肩', '连衣裙', '最', 'IN', '穿', '出', '女神', '气质']},
#  {'doc_title': ['iTune',
#    'Store',
#    '扩展',
#    '计划',
#    '未',
#    '包括',
#    '三个',
#    '亚洲',
#    '最大',
#    '市场']},
#  {'doc_title': ['管理', '艺术', '驾驭', '艺术']},
#  {'doc_title': ['逾千', '男女', '全身', '涂红', '慕尼黑', '裸舞']},
#  {'doc_title': ['Windows',
#    'Phone',
#    '8',
#    'SDK',
#    '泄漏',
#    '内置',
#    '诺基亚',
#    '3D',
#    '地图']},
#  {'doc_title': ['广东', '一', '男童', '被', '恙虫', '咬伤', '命根', '险', '丧命']},
#  {'doc_title': ['请用', '3', '个', '关键词', '来', '概括', '自己']},
#  {'doc_title': ['图片', '标注', '服务', 'Stipple', '图中', '标注', '产品', '购买', '链接']},
#  {'doc_title': ['喝', '了', '牛初乳', '5', '岁', '女孩', '提早来', '月经']},
#  {'doc_title': ['葡萄牙', '白色', '豪宅', '优雅', '的', '几何图形']},
#  {'doc_title': ['创业者', '乐园', '一个', '人', '和', '一群', '人', '的', '车库']},
#  {'doc_title': ['本土', '设计师', '行业', '陷阱']},
#  {'doc_title': ['Jean', 'Paul', 'Gaultier', '座上客']},
#  {'doc_title': ['报告', '称', '60%', '开发者', '计划', '为', '微软', 'WP', '开发', '程序']},
#  {'doc_title': ['七大', '性爱', '杀手', '女人', '绝对', '要', '重视']},
#  {'doc_title': ['当',
#    '妻子',
#    '的',
#    '收入',
#    '超过',
#    '丈夫',
#    '时',
#    '你',
#    '认为',
#    '婚姻',
#    '会',
#    '长久',
#    '吗']},
#  {'doc_title': ['世上', '最', '美丽', '最', '危险', '的', '白沙滩', '海姆', '斯', '沙滩']},
#  {'doc_title': ['建', '在', '酒窖', '上', '的', '小镇', '探访', '香槟', '诞生地']},
#  {'doc_title': ['这是', '一群', '感性', '优先', '理性', '匮乏', '不可', '解释', '的', '人群']},
#  {'doc_title': ['搭载', 'Tegra', '处理器', '的', 'Tesla', '电动', '轿车', '周五', '出货']},
#  {'doc_title': ['奢华', '家居', '品鉴', '欧洲', '现代', '厨房', '设计']},
#  {'doc_title': ['美体', '研究院', '花果', '排毒', '从', '内', '瘦', '出来']},
#  {'doc_title': ['小',
#    'POS',
#    '机涉',
#    '灰色',
#    '大',
#    '产业',
#    '南宁',
#    '查处',
#    '49',
#    '个',
#    '套现',
#    '窝点']},
#  {'doc_title': ['爱爱时', '走神', '我', '被', '老公', '扇大', '耳光']},
#  {'doc_title': ['爱马仕', '新作', '大明', '火', '珐琅', '怀表']},
#  {'doc_title': ['适当', '的', '自慰', '可以', '提高', '你', '的', '性爱', '质量']},
#  {'doc_title': ['中国',
#    '奥运',
#    '代表团',
#    '的',
#    '入场',
#    '礼服',
#    '终于',
#    '千呼万唤',
#    '始',
#    '出来',
#    '毫不',
#    '意外',
#    '的',
#    '今年',
#    '又',
#    '是',
#    '红',
#    '黄',
#    '两色',
#    '相配']},
#  {'doc_title': ['薄涛',
#    '时装品牌',
#    '在',
#    '第',
#    '27',
#    '届',
#    '香港',
#    '秋冬',
#    '时装节',
#    '亮相',
#    '并',
#    '做',
#    '专场',
#    '服装',
#    '发布',
#    '取得',
#    '圆满成功']},
#  {'doc_title': ['微软', '借', '收购', '推出', '巨型', '平板', '电脑']},
#  {'doc_title': ['Facebook',
#    '或',
#    '涉足',
#    '在线',
#    '支付',
#    '挑战',
#    'PayPal',
#    '霸主',
#    '之位']},
#  {'doc_title': ['面板', '下半年', '需求', '增幅', '再', '降', '中企', '结束', '短暂', '回暖']},
#  {'doc_title': ['智能机', '市场', '赤潮', '来临', '联想', '能否', '复制', 'PC', '成功']},
#  {'doc_title': ['联发科', '遭', '芯片', '厂商', '围剿', '营收', '持续', '两月', '下降']},
#  {'doc_title': ['麻省理工', '个人化', '基因', '测序', '仪', '问世']},
#  {'doc_title': ['苹果', '为', '员工', '提供', '折扣', '买', 'Mac', '便宜', '500', '美元']},
#  {'doc_title': ['京东',
#    '商城',
#    '刘强',
#    '东',
#    '电商',
#    '入驻',
#    '不同',
#    '平台',
#    '需要',
#    '平衡',
#    '销量']},
#  {'doc_title': ['T',
#    '.',
#    'H',
#    '.',
#    'Capital',
#    '称',
#    '百度',
#    '目前',
#    '股价',
#    '被',
#    '低估',
#    '评级',
#    '买入']},
#  {'doc_title': ['微软', '2010', '商用', '平台', '发布', '最新', '报道']},
#  {'doc_title': ['员工',
#    '不',
#    '理解',
#    '蔡明介',
#    '传',
#    '晨星',
#    '被',
#    '联发科',
#    '收购',
#    '现',
#    '离职',
#    '潮']},
#  {'doc_title': ['Windows', 'logo', '变迁', 'Win8', '重回', '1985', '头版', '风格']},
#  {'doc_title': ['500',
#    '条',
#    '6',
#    '项',
#    '名片',
#    '式',
#    '电话本',
#    '4',
#    '个',
#    '电话',
#    '2',
#    '个',
#    'E',
#    'mail',
#    '地址']},
#  {'doc_title': ['经济型', '酒店', '管理', '阵痛', '博弈', '规模化', '与', '标准化']},
#  {'doc_title': ['雅虎', '和', '脸谱', '就', '专利', '纠纷', '达成', '和解']},
#  {'doc_title': ['iPhone',
#    '5',
#    '死敌',
#    '三星',
#    '5.5',
#    '寸',
#    'Galaxy',
#    'Note',
#    '2',
#    '曝光']},
#  {'doc_title': ['关注', '网络', '暴力', '践', '行者', '与', '受害者', '之辩']},
#  {'doc_title': ['新',
#    'iPhone',
#    '配',
#    'in',
#    'cell',
#    '触控',
#    '面板',
#    '8',
#    '月',
#    '亮相',
#    '更',
#    '轻薄']},
#  {'doc_title': ['马化腾', '对话', '李彦宏', '提议', '设', '协调局', '管', '互联网']},
#  {'doc_title': ['诺基亚', '高管', '确认', 'Lumia', '将', '加入', 'PureView', '技术']},
#  {'doc_title': ['戈壁', '投资', '童玮亮', '图片', '社交', '上', '云端', '才', '有', '未来']},
#  {'doc_title': ['英特尔',
#    '7',
#    '月',
#    '将',
#    '举行',
#    '会议',
#    '或',
#    '将',
#    '推动',
#    '超极本',
#    '降价']},
#  {'doc_title': ['苹果', '赢得', '平台', '战争', '真正', '原因', '获得', '开发者', '青睐']},
#  {'doc_title': ['广东省', '工商局', '开', '网店', '不', '强制', '工商', '注册']},
#  {'doc_title': ['iOS',
#    '或',
#    '成为',
#    '谷歌',
#    '移动',
#    '收入',
#    '最大',
#    '来源',
#    '营收',
#    '贡献',
#    '2%']},
#  {'doc_title': ['江苏', '消协', '发布', '投诉', '数据', '苹果', '售后', '问题', '多']},
#  {'doc_title': ['图文', '1992', '年', '巴塞罗那奥运会', '回顾', '乔丹']},
#  {'doc_title': ['08', '07', '15', '46']},
#  {'doc_title': ['图文', '海南', '海警', '参加', '奥运', '安保', '海上', '反恐', '演练']},
#  {'doc_title': ['AOL',
#    '公布',
#    '重组',
#    '计划',
#    '成立',
#    '三个',
#    '运营',
#    '部门',
#    '及',
#    '后勤',
#    '支持']},
#  {'doc_title': ['任伟光', 'HTC', '主要', '精力', '仍', '将', '放在', '高端', '手机', '市场']},
#  {'doc_title': ['网络', '教育', '平台', 'BenchPrep', '融资', '600', '万美元']},
#  {'doc_title': ['搜狐', '女人', '频道', '生活', '新', '栏目']},
#  {'doc_title': ['你',
#    '是否',
#    '被',
#    '太',
#    '多',
#    '烦恼',
#    '围绕',
#    '觉得',
#    '什么',
#    '都',
#    '做',
#    '不好',
#    '有没有',
#    '曾经',
#    '怀疑',
#    '自己',
#    '是否',
#    '很',
#    '糟糕']},
#  {'doc_title': ['西班牙', '高贵', '奢华', '的', '皇室', '珠宝']},
#  {'doc_title': ['轩少', '儿子', '请', '从', '我', '身边', '搬走']},
#  {'doc_title': ['新闻', '发布会', '文字', '直播']},
#  {'doc_title': ['很多',
#    '圣诞',
#    '限定',
#    '美食',
#    '都',
#    '需要',
#    '提前',
#    '订',
#    '网购',
#    '也',
#    '要',
#    '几天',
#    '才能',
#    '寄',
#    '到',
#    '这',
#    '段时间',
#    '正好',
#    '做',
#    '这些',
#    '事']},
#  {'doc_title': ['幼', '细纹', '即时', '修复', '能力']},
#  {'doc_title': ['锁骨', '沟', '为什么', '性感']},
#  {'doc_title': ['明星',
#    '魅力',
#    '明星',
#    '穿衣',
#    '之道',
#    '时装',
#    '新品',
#    '发布',
#    '及',
#    '模特',
#    '写真']},
#  {'doc_title': ['印象派', '新秀', '9', '岁', '小', '莫奈', '卖画成', '富翁']},
#  {'doc_title': ['口述', '同事', '小帅哥', '总', '纠缠', '已婚', '的', '我']},
#  {'doc_title': ['中国', '最', '新锐', '上升', '最快', '的', '时尚', '摄影师']},
#  {'doc_title': ['华硕', 'HTC', '多', '设备', '将', '升至', '安卓', '4.1']},
#  {'doc_title': ['完全', '体', '超极本', '标准', '出炉', '将', '具备', '3D', '显示', '功能']},
#  {'doc_title': ['甲骨文', '将', '收购', '网络分析', '公司', '较量', '竞争对手']},
#  {'doc_title': ['如家', '5980', '万', '收购', 'e', '家', '快捷酒店']},
#  {'doc_title': ['调查', '显示', '诺基亚', 'Lumia', '900', '用户', '满意度', '高达', '96%']},
#  {'doc_title': ['图说',
#    '2012',
#    '伦敦',
#    '奥运会',
#    '观赛',
#    '新气象',
#    '将',
#    '有',
#    '49',
#    '亿人',
#    '观看']},
#  {'doc_title': ['雷军',
#    '称',
#    '小米',
#    '手机',
#    '年底',
#    '将',
#    '进军',
#    '台湾',
#    '市场',
#    '目标',
#    '前三强']},
#  {'doc_title': ['百度', '第二季度', '净利润', '27.7', '亿元', '同比', '增长', '69.6%']},
#  {'doc_title': ['苹果', 'iphone', '5', '谍', '照曝光']},
#  {'doc_title': ['视频', 'Google', '流', '媒体播放器', 'Nexus', 'Q']},
#  {'doc_title': ['90', '后', '一代', '开始', '创业', '与', '前辈', '观点', '存', '差异']},
#  {'doc_title': ['7', '月', '31', '日', '中国', '概念股', '新东方', '跌', '8.79%']},
#  {'doc_title': ['百视通', '3000', '万美元', '入股', '风行', '在线']},
#  {'doc_title': ['周鸿祎', '互联网', '将', '冲击', '传统', '手机', '和', '电信', '商']},
#  {'doc_title': ['传', '百思买', '创始人', '寻求', '私有化', '担心', '股权', '价值', '下降']},
#  {'doc_title': ['趣高', '网田琼', '做', '中国', '本土', '的', 'Grubwithus']},
#  {'doc_title': ['中兴', '国内', '首款', 'WindowsPhone', '手机', '发布']},
#  {'doc_title': ['诺基亚',
#    '将',
#    '推',
#    '三款',
#    'S40',
#    '触屏',
#    '手机',
#    '最低',
#    '售价',
#    '仅',
#    '63',
#    '欧元']},
#  {'doc_title': ['苹果',
#    '今天',
#    '关闭',
#    'MobileMe',
#    '用户',
#    '数据',
#    '迁移',
#    '至',
#    'iCloud']},
#  {'doc_title': ['Ultrabook',
#    '上半年',
#    '出货',
#    '仅',
#    '50',
#    '万台',
#    '全年',
#    '预期',
#    '100',
#    '万台']},
#  {'doc_title': ['微软', '计划', '2014', '年', '终止', 'Windows', 'XP', '服务']},
#  {'doc_title': ['传', '科技', '博客', 'GigaOm', '待价而沽', '欲', '卖', '给', '彭博社', '等']},
#  {'doc_title': ['诺基亚', '移动电话']},
#  {'doc_title': ['盛拓', '传媒', 'CEO', '秦致', '垂直', '网站', '侧重', '互动']},
#  {'doc_title': ['分析',
#    '称高',
#    '定价',
#    '或',
#    '将',
#    '损害',
#    'Office',
#    '2013',
#    '市场',
#    '地位']},
#  {'doc_title': ['施密特', '透露', '谷歌', '一直', '渴望', '进入', '硬件', '领域']},
#  {'doc_title': ['近九成', '家用空调', '细菌', '超标']},
#  {'doc_title': ['淘宝',
#    '已',
#    '开始',
#    '预售',
#    'iPhone5',
#    '作法',
#    '是',
#    '抢购',
#    '后',
#    '转手',
#    '卖']},
#  {'doc_title': ['逐步', '建立', '全新', '电子信息', '政务', '平台']},
#  {'doc_title': ['Jetpac',
#    '聚合',
#    '社交',
#    '好友',
#    '的',
#    '旅行',
#    '照片',
#    '获杨',
#    '致远',
#    '投资']},
#  {'doc_title': ['郭台铭', '抛', '富人', '税', '提议', '瞄准', '台湾', '前', '300', '富人']},
#  {'doc_title': ['传', '百思买', '创始人', '舒尔兹', '招募', '团队', '迎接', '私有化', '计划']},
#  {'doc_title': ['DailyBurn', '燃烧', '吧', '脂肪']},
#  {'doc_title': ['北京',
#    '联通',
#    '免费',
#    '提速',
#    '限制',
#    '接入',
#    '终端',
#    '数量',
#    '最多',
#    '4',
#    '台']},
#  {'doc_title': ['家电', '节能', '新政', '满月酒', '难', '摆']},
#  {'doc_title': ['李鬼', '返利', '网站', '涉嫌', '传销', '被查']},
#  {'doc_title': ['苏宁', '电器', '上半年', '净利', '17.45', '亿元', '同比', '下降', '近三成']},
#  {'doc_title': ['诺基亚',
#    '董事长',
#    '暗示',
#    '如',
#    'Windows',
#    '8',
#    '失败',
#    '将',
#    '选择',
#    '安卓']},
#  {'doc_title': ['陈善广', '神九', '多项', '航天', '医学', '实验', '首次', '在', '轨', '使用']},
#  {'doc_title': ['专家',
#    '称',
#    '三峡',
#    '蓄水',
#    '后',
#    '1',
#    '至',
#    '3',
#    '年',
#    '发生',
#    '地质灾害',
#    '可能性',
#    '大']},
#  {'doc_title': ['悠哉',
#    '8',
#    '周年',
#    '让利',
#    '8000',
#    '万',
#    '正式',
#    '加入',
#    '旅游',
#    'OTA',
#    '价格战']},
#  {'doc_title': ['Nexus', '7', '平板', '正式', '出货', '多家', '零售商', '销售一空']},
#  {'doc_title': ['东方', '企业家', '杂志', '联想', '移动', '互联网', '司令', '官刘军']},
#  {'doc_title': ['研究', '称', '白天', '过度', '嗜睡', '或', '可', '导致', '老年痴呆']},
#  {'doc_title': ['UC', '将建', '移动游戏', '开放平台', '已', '收购', '手游', '平台', '九游网']},
#  {'doc_title': ['2012', '派代', '电子商务', '年会']},
#  {'doc_title': ['美国', '听证', '中国', '创新', '有何', '目的']},
#  {'doc_title': ['三星', '启动', '危机', '经营', '要求', '员工', '六点半', '上班']},
#  {'doc_title': ['巴西',
#    '囚犯',
#    '可',
#    '通过',
#    '读书',
#    '缩减',
#    '刑期',
#    '读一',
#    '本书',
#    '减刑',
#    '4',
#    '天']},
#  {'doc_title': ['HTC', '否认', '台湾', '裁员', '员工', '合约', '到期', '自然', '终止']},
#  {'doc_title': ['第三方', '支付', '获牌', '满', '一周年', '依附于', '银行', '存', '隐患']},
#  {'doc_title': ['优酷', '存在', '大量', '盗版', '影视剧']},
#  {'doc_title': ['摩托罗拉', '移动', '将', '不会', '受到', '进口', '禁令', '生效', '影响']},
#  {'doc_title': ['前', 'T', 'Mobile', '美国', 'CEO', '火速', '转投', '沃达丰']},
#  {'doc_title': ['默多克', '学习', '布隆', '伯格', '好榜样']},
#  {'doc_title': ['英国',
#    '在线',
#    '投资',
#    '管理',
#    '网站',
#    'Nutmeg',
#    '获',
#    '融资',
#    '530',
#    '万美元']},
#  {'doc_title': ['刘强', '东', '首度', '公开', '承认', '恋情', '西红柿', '门', '不是', '炒作']},
#  {'doc_title': ['桔子', '酒店', '完成', '第三轮', '融资', '凯雷汉庭', '或', '先后', '抄底']},
#  {'doc_title': ['消息', '称', '苹果', 'Google', '竞购', '柯达', '专利']},
#  {'doc_title': ['令人', '叹为观止', '的', '微缩', '艺术', '组图']},
#  {'doc_title': ['报告', '称', '诺基亚', 'Lumia', '系列', '超过', 'iPhone', '同期', '销量']},
#  {'doc_title': ['红色', '版本', '三星', 'Galaxy', 'S', 'III', '本周', '在', '美', '上市']},
#  {'doc_title': ['Android',
#    '和',
#    'iOS',
#    '霸占',
#    '美国',
#    '智能手机',
#    '市场',
#    '份额',
#    '超',
#    '9',
#    '成']},
#  {'doc_title': ['返利', '网', '中', '枪', '疑要', '改名', '九成', '网友', '力挺', '不', '改名']},
#  {'doc_title': ['科学家', '为', '抑制', '全球', '变暖', '可能', '将', '蓝天', '变成', '白色']},
#  {'doc_title': ['伦敦', '奥运会', '开幕', 'Twitter', '用户', '发帖', '996', '万条']},
#  {'doc_title': ['首届', '阿里', '云', '开发者', '大赛', '启动', '助', '开发者', '实现', '梦想']},
#  {'doc_title': ['赠台大', '熊猫', '圆圆', '显', '怀孕', '征兆']},
#  {'doc_title': ['2007', '中国科协', '年会', '8', '日', '上午', '在', '武汉', '开幕']},
#  {'doc_title': ['用',
#    '一条',
#    '马卡龙色',
#    '的',
#    '丝巾',
#    '就',
#    '能',
#    '编出',
#    '度假',
#    '风格',
#    '的',
#    '编发',
#    '将',
#    '难驾驭',
#    '的',
#    '丝巾',
#    '盘发']},
#  {'doc_title': ['一家', '6', '口', '何以', '在', '高级', '套间', '全', '染上', '性病']},
#  {'doc_title': ['口述', '看见', '老公', '抱', '着', '闺蜜', '大腿', '午休']},
#  {'doc_title': ['LV', '推出', '全新', '奢华', 'Nomades', '家饰', '系列']},
#  {'doc_title': ['解读', '时尚', '创造', '历史']},
#  {'doc_title': ['2009', '春夏', '高级', '定制', '3', '大', '亮点']},
#  {'doc_title': ['我们', '的', '爱情', '结束', '于', '我', '没有', '钱', '买', '楼房']},
#  {'doc_title': ['度假', '奢地', '隐于', '科孚岛', '的', '梦幻', '别墅']},
#  {'doc_title': ['4', '个', '步骤', '从', '闺蜜', '变为', '正牌', '男友']},
#  {'doc_title': ['G', 'TALK', '沙龙', '从', '产业链', '变化', '看', '无线', '产业', '未来']},
#  {'doc_title': ['玉器', '收藏', '在', '真真假假', '中', '摇摆']},
#  {'doc_title': ['厂商',
#    '部署',
#    'Android',
#    '4.1',
#    '无',
#    '时间表',
#    '谷歌',
#    '未',
#    '扛起',
#    '责任']},
#  {'doc_title': ['7',
#    '月',
#    '号',
#    '娇点',
#    'CosmoGIRL',
#    '将',
#    '于',
#    '6',
#    '月',
#    '25',
#    '日',
#    '隆重',
#    '上市',
#    '敬请',
#    '关注']},
#  {'doc_title': ['脂肪', '提取', '干细胞', '培育出', '人骨', '或', '替换', '受损', '骨头']},
#  {'doc_title': ['侧', '开衩', '大', '长裙', '勾勒', '完美', '长腿', '线条']},
#  {'doc_title': ['广东', '联通', '3G', '网络', '持续', '大跃进']},
#  {'doc_title': ['大热天', '油性皮肤', '如何', '选择', '护肤品']},
#  {'doc_title': ['当',
#    '妻子',
#    '的',
#    '收入',
#    '超过',
#    '丈夫',
#    '时',
#    '你',
#    '认为',
#    '婚姻',
#    '会',
#    '长久',
#    '吗']},
#  {'doc_title': ['非洲', '之旅', '感受', '肯尼亚', '的', '异域', '风光']},
#  {'doc_title': ['夏日', '高分', '搭配', '纯色', '系让', '你', '脱颖而出']},
#  {'doc_title': ['美', '非诚', '勿扰', '尺度', '大', '相亲', '似', '一夜情']},
#  {'doc_title': ['巧', '搭', '淡雅', '无袖', '背心', '小清', '新风', '走', '起来']},
#  {'doc_title': ['流落', '异国', '街头', '却', '成为', 'AV', '女主角']},
#  {'doc_title': ['世间', '极致', 'Hennessy', '轩尼诗', '李察', '干邑']},
#  {'doc_title': ['女性', '的', '食欲', '与', '性欲', '存在', '紧密', '的', '关系']},
#  {'doc_title': ['编辑部', '热荐', '清爽', '夏日', '控油', '祛痘', '单品', '榜']},
#  {'doc_title': ['欧米茄', '第二家', '旗舰店', '大连', '开幕']},
#  {'doc_title': ['英国', '家猫', '示警', '拯救', '已', '昏迷', '的', '女主人']},
#  {'doc_title': ['什么', '阻止', '了', '女性', '参政', '的', '脚步']},
#  {'doc_title': ['我', '无法忍受', '老公', '把', '我', '当成', '性虐', '玩偶']},
#  {'doc_title': ['长期', '看', '色情片', '性', '能力', '会', '早衰', '30', '年']},
#  {'doc_title': ['甜甜', '小', '蜜糖', '梦幻', '糖果', '浓情', '又', '卖萌']},
#  {'doc_title': ['最', '浪漫', '的', '紫色', '沙滩', '加州', '帕非佛', '沙滩']},
#  {'doc_title': ['模特', '新秀', '汇聚', '郑州', '上海', '国际', '模特大赛', '完美', '起航']},
#  {'doc_title': ['网友', '曝光', '朱时茂', '为', '80', '后', '女友', '庆生', '照']},
#  {'doc_title': ['摇曳', '百褶裙', '复古', '小', '清新', '穿', '出', '女人味']},
#  {'doc_title': ['杰西卡', '派尔', '魅力', '演绎', 'Tiffany', '珠宝']},
#  {'doc_title': ['让', '女人', '远离', '伤害', '的', '二十四条', '忠告']},
#  {'doc_title': ['口述', '性冷淡', '的', '老公', '让', '女', '下属', '怀孕']},
#  {'doc_title': ['女人', '长期', '得不到', '性爱', '的', '后果']},
#  {'doc_title': ['外滩', 'YAWARAGI', '怀石', '邂逅', '顶级', '甜点']},
#  {'doc_title': ['ARMANI', 'EXCHANGE', '夏季', '精彩', '冒险', '系列']},
#  {'doc_title': ['一是',
#    '关于',
#    '内衣',
#    '的',
#    '品牌',
#    '大多数',
#    '人',
#    '认为',
#    '无所谓',
#    '反正',
#    '穿',
#    '在',
#    '里边']},
#  {'doc_title': ['哈利', '波特', '与', '凤凰社', '2003', '9', '2007', '6']},
#  {'doc_title': ['黄配', '蓝超', '抢眼', '高温', '天学', '最', '时髦', '撞色']},
#  {'doc_title': ['乳房', '大小', '是否', '与', '性高潮', '有', '关系']},
#  {'doc_title': ['法国', '纪梵希净', '白盈采', '系列']},
#  {'doc_title': ['再', '不', '结婚', '就要', '引', '公愤', '的', '大', '明星', '们']},
#  {'doc_title': ['又',
#    '到',
#    '美白季',
#    '让',
#    '我们',
#    '白上',
#    '更白',
#    '最',
#    '信赖',
#    '高效',
#    '美白',
#    '精华',
#    '评测',
#    '帮',
#    '你',
#    '选择',
#    '最',
#    '信任',
#    '的',
#    '美白',
#    '产品']},
#  {'doc_title': ['中国', '奢侈品', '消费', '增幅', '全球', '最高']},
#  {'doc_title': ['刘璇', '今年', '1', '月', '美国', '结婚', '男友', '是', '副教授']},
#  {'doc_title': ['富豪', '的', '岛主', '梦', '能', '移动', '的', '豪华', '人工岛']},
#  {'doc_title': ['雅典奥运', '美女', '军团']},
#  {'doc_title': ['哪个', '星座', '的', '虚荣心', '最强']},
#  {'doc_title': ['迈克', '菲尔', '普斯协手', 'SPEEDO']},
#  {'doc_title': ['八卦', '明星脸', '赵雅芝', '暴瘦', '气质', '不变']},
#  {'doc_title': ['八卦', '明星脸', '鲁豫', '手臂', '暴瘦似', '骷髅']},
#  {'doc_title': ['09', '秋冬', '女装', '周之', '复古', '仍', '当道']},
#  {'doc_title': ['独生子女', '究竟', '是', '怎样', '的', '一群', '人']},
#  {'doc_title': ['当',
#    '妻子',
#    '的',
#    '收入',
#    '超过',
#    '丈夫',
#    '时',
#    '你',
#    '认为',
#    '婚姻',
#    '会',
#    '长久',
#    '吗']},
#  {'doc_title': ['实录', '我爱你', '和', '罩杯', '大小', '没关系']},
#  {'doc_title': ['老公', '搞大', '闺蜜', '肚子', '让', '我', '做饭', '庆祝']},
#  {'doc_title': ['4', '种', '立体', '花朵', '裙', '勾勒', '柔美', '女性', '气质']},
#  {'doc_title': ['有', '了', '房子', '爱情', '才', '可以', '在', '里面', '无限', '发挥']},
#  {'doc_title': ['搜狐', '女人', '频道', '生活', '新', '栏目']},
#  {'doc_title': ['外国', '名模', '艾米', '韦伯']},
#  {'doc_title': ['外滩', 'YAWARAGI', '怀石', '邂逅', '顶级', '甜点']},
#  {'doc_title': ['李静', '芳香', '之', '旅受', '格拉斯', '市长', '高', '规格', '礼遇']},
#  {'doc_title': ['有关', '婚检', '的', '一些', '数据']},
#  {'doc_title': ['佰草集', '新', '玉润', '沁养', '肌肤', '若玉之泽']},
#  {'doc_title': ['cecilia', '_', 'pepsi', '将来', '打算', '尝试', '的']},
#  {'doc_title': ['高潮',
#    '背后',
#    '的',
#    '秘密',
#    '9',
#    '极少数',
#    '情况',
#    '下',
#    '高潮',
#    '在',
#    '没有',
#    '性刺激',
#    '中',
#    '达到']},
#  {'doc_title': ['美丽', '天书', '轻松', '按摩', '变', '身', '小腰', '精']},
#  {'doc_title': ['吴辰君', '北京', '办', '婚礼', '低调', '嫁入', '豪门']},
#  {'doc_title': ['今夏', '必学', '的', '性感', '小', '绝招', '回头率', '超高']},
#  {'doc_title': ['王晶讽', '港姐', '身材', '差', '能', '全部', '淘汰', '吗']},
#  {'doc_title': ['妻子', '等', '服刑', '丈夫', '20', '年', '相聚', '后闹', '离婚']},
#  {'doc_title': ['米兰', '时装周', '上', '的', '最潮', '村姑']},
#  {'doc_title': ['可', '增加', '精子', '产量', '的', '助性', '水果']},
#  {'doc_title': ['梁冠',
#    '礼服',
#    '钗',
#    '钿',
#    '礼衣',
#    '中国',
#    '红',
#    '为主',
#    '色调',
#    '令人',
#    '耳目',
#    'NE',
#    'TIGER',
#    '推出',
#    '中式',
#    '婚礼服']},
#  {'doc_title': ['男人', '生命', '中', '那些', '最', '重要', '的', '第一次']},
#  {'doc_title': ['偶尔', '出轨', '就', '一辈子', '都', '是', '坏', '女人', '吗']},
#  {'doc_title': ['LANCOME', '兰蔻', '根源', '补养', '系列', '7', '月底', '震撼', '上市']},
#  {'doc_title': ['威士忌', '巨头', '帝', '亚吉', '欧', '豪赌', '中国', '市场']},
#  {'doc_title': ['七成', '中国', '女性', '从来不', '穿', '丁字裤']},
#  {'doc_title': ['谷歌', '驳斥', '微软', 'Android', '手机', '沦为', '僵尸', '网络', '说法']},
#  {'doc_title': ['雪龙号', '起航', '赴', '北极', '科考', '高纬度', '航道', '或', '可达', '北极点']},
#  {'doc_title': ['网络', '代购', '借', '香港', '发票', '令', '奢侈品', '高仿', '货成', '正品']},
#  {'doc_title': ['雷军', '否认', '小米', '暴利', '说', '周鸿祎', '使', '我们', '陷', '两难']},
#  {'doc_title': ['邮箱', '网访', '搜狐', '邮件', '中心', '负责人', '李红', '文字', '实录']},
#  {'doc_title': ['2009', '第二届', '中国', '化妆品', '大会', '大会', '流程']},
#  {'doc_title': ['女友', '怀孕', '后', '我', '被', '告知', '孩子', '不是', '我', '的']},
#  {'doc_title': ['飞行员', '外套', '+', '裤装', '中性', '范儿']},
#  {'doc_title': ['洞房', '夜见', '红', '老公', '居然', '怀疑', '我', '造假']},
#  {'doc_title': ['美', '非诚', '勿扰', '尺度', '大', '相亲', '似', '一夜情']},
#  {'doc_title': ['美丽', '天书', '妙招', '让', '刘海', '不再', '软塌塌']},
#  {'doc_title': ['进', '阶级', '豹纹', '上衣', '长裤', '外套', '皮草']},
#  {'doc_title': ['女孩子', '做', '任何', '事情', '都', '要', '充满', '自信']},
#  {'doc_title': ['女人', '创造', '历史']},
#  {'doc_title': ['少女',
#    '因',
#    '10',
#    '元',
#    '钱',
#    '被',
#    '7',
#    '名',
#    '同学',
#    '殴打',
#    '拍',
#    '裸照']},
#  {'doc_title': ['男人', '婚外情', '血型', '分析', '其中', '秘密']},
#  {'doc_title': ['超萌', '石猴', '六宗', '罪', '暗藏', '致命', '杀机']},
#  {'doc_title': ['英国女王', '坦言', '曾经', '疏远', '子女']},
#  {'doc_title': ['特大', '淫秽', '网站', '被关', '百万', '青少年', '受害']},
#  {'doc_title': ['番茄',
#    '美容',
#    '液',
#    '番茄',
#    '榨汁',
#    '后',
#    '可以',
#    '拿来',
#    '擦',
#    '脸',
#    '有',
#    '不错',
#    '的']},
#  {'doc_title': ['赵普投', '凤凰卫视', '激怒', '央视', '节目', '被删']},
#  {'doc_title': ['3',
#    '.',
#    '阅读',
#    '本专题',
#    '后',
#    '你',
#    '最',
#    '喜欢',
#    '哪个',
#    '性',
#    '节目',
#    '主持人']},
#  {'doc_title': ['空调', '房', '必备', '针织', '开衫', '保暖', '好', '搭', '有', '型']},
#  {'doc_title': ['6', '月', '16', '日', '各', '星座', '运势', '总览']},
#  {'doc_title': ['关于',
#    '世界',
#    '第一个',
#    '试管婴儿',
#    '以及',
#    '中国',
#    '第一个',
#    '试管婴儿',
#    '的',
#    '近况']},
#  {'doc_title': ['八卦', '明星脸', '杨钰莹', '发福', '小腹', '隆起']},
#  {'doc_title': ['22', '年', '成就', '一部', '传奇']},
#  {'doc_title': ['丈夫', '离奇', '失忆', '打电话', '问妻', '自己', '是', '谁']},
#  {'doc_title': ['你',
#    '企图',
#    '通过',
#    '不断',
#    '提及',
#    '你',
#    '俩',
#    '的',
#    '关系',
#    '来',
#    '保持',
#    '两人',
#    '关系',
#    '的',
#    '热度']},
#  {'doc_title': ['掌控', '肤温', '顽抗', '紫外线', '&', '室内外', '温差']},
#  {'doc_title': ['苹果', '在线', '翻新', 'MacBook', 'Pro', '起售', '929']},
#  {'doc_title': ['新浪', '微博', '推', '普通用户', '版微博', '置顶', '功能', '需', '开通', '会员']},
#  {'doc_title': ['推', 'iPad', 'mini', '存', '明确', '经济', '原因']},
#  {'doc_title': ['消息',
#    '称',
#    '华为',
#    '或',
#    '推',
#    '四款',
#    '联发科',
#    'MT6577',
#    '平台',
#    '双核',
#    '手机']},
#  {'doc_title': ['诺基亚', '4100', '万', '像素', '手机', '预售', '成像', '效果', '难比', '单反']},
#  {'doc_title': ['旧货', '交易', 'Yardsale', '用', 'Facebook', '账户', '实现', '实名制']},
#  {'doc_title': ['百思买', '股东大会', '谋', '转型', '计划', '拓展', '企业', '市场']},
#  {'doc_title': ['在',
#    'iOS',
#    '6',
#    '中',
#    '下载',
#    '或',
#    '升级',
#    '应用',
#    '不再',
#    '需要',
#    '输入',
#    '密码']},
#  {'doc_title': ['PayPal',
#    '收购',
#    '移动',
#    '支付',
#    '商',
#    'Card',
#    '.',
#    'io',
#    '增加',
#    '创业',
#    'DNA']},
#  {'doc_title': ['电子商务', '市场份额', '居', '互联网', '首位']},
#  {'doc_title': ['索尼', '合资', '子公司', '22', '亿美元', '收购', 'EMI']},
#  {'doc_title': ['宏达', '电', '关闭', '巴西', '办事处', '不', '影响', '现有', '客户服务']},
#  {'doc_title': ['索尼', '与', 'PlayFirst', '合作开发', '电影', '题材', '手机游戏']},
#  {'doc_title': ['中国', '科考队', '进入', '北极圈', '内', '开展', '科学考察']},
#  {'doc_title': ['腾讯', '规模', '最大', '全站', '改版', '科技频道', '变', '身', '博客']},
#  {'doc_title': ['华为', '成为', '首批', 'Windows', 'Phone', '8', '手机', '供应商']},
#  {'doc_title': ['财付', '通', '开通', '手机短信', '生活', '缴费', '业务']},
#  {'doc_title': ['5', '25', '格力', '事件', '耶鲁', '策动', '格力', '事件', '内幕']},
#  {'doc_title': ['1', '你', '是否', '看好', 'AMD', '分拆', '制造', '业务']},
#  {'doc_title': ['Office2013', '下周', '将', '发布', 'Beta', '版']},
#  {'doc_title': ['竞拍', '购物', '网站', '偶尔', '网', '59', '元', '成交', '宝马', '汽车']},
#  {'doc_title': ['研究', '显示', '睡眠', '问题', '或', '导致', '老年人', '认知', '能力', '下降']},
#  {'doc_title': ['研究',
#    '称',
#    '史前',
#    '地球',
#    '气候变化',
#    '与',
#    '温室',
#    '气体',
#    '并',
#    '无',
#    '关联性']},
#  {'doc_title': ['用友', '完成', '管理层', '调整', '原', '总裁', '李友', '改赴', '子公司', '上任']},
#  {'doc_title': ['三星', '打法', '先', '模仿', '对手', '再', '吃掉', '对手']},
#  {'doc_title': ['唯冠称', '有', 'iPad', '商标', '可', '清偿债务']},
#  {'doc_title': ['苏宁',
#    '易购',
#    '宣布',
#    '设置',
#    '1800',
#    '家',
#    '门店',
#    '为',
#    '用户',
#    '网',
#    '购自',
#    '提',
#    '点']},
#  {'doc_title': ['电视', '支付', '前景', '堪忧', '技术', '安全', '待', '完善']},
#  {'doc_title': ['康宁', '受', 'LCD', '行业', '低迷', '拖累', '二季', '净利', '降', '四成']},
#  {'doc_title': ['英国',
#    '15',
#    '岁',
#    '少女',
#    '患',
#    '遗传性',
#    '早衰',
#    '症',
#    '貌似',
#    '45',
#    '岁',
#    '妇人']},
#  {'doc_title': ['天猫', '公布', '下半年', '让利', '举措', '10', '亿', '优惠', '定期', '派送']},
#  {'doc_title': ['华硕',
#    '推出',
#    '首款',
#    'Windows',
#    'RT',
#    '系统',
#    '平板',
#    '电脑',
#    '10',
#    '月',
#    '上市']},
#  {'doc_title': ['雷士', '阎焱', '曾', '向', '吴', '长江', '索', '3%', '个人', '期权']},
#  {'doc_title': ['愤怒', '小鸟', '疯狂', '揽金', '国内', '代理商', '难分', '羹']},
#  {'doc_title': ['长牙', '食人鱼', '疑', '入侵', '美国', '专咬', '男性', '生殖器']},
#  {'doc_title': ['三问', '衰老', '的', '诺基亚']},
#  {'doc_title': ['李泽楷', '叛逆', '游戏', '借壳', '分拆', '之', '虚虚实实']},
#  {'doc_title': ['天宫', '一号', '收到', '祖国', '第一', '封电子邮件']},
#  {'doc_title': ['专家', '称', '喝奶', '也', '要', '讲', '科学', '牛奶', '可能', '有害', '健康']},
#  {'doc_title': ['谷歌', '向', '甲骨文', '索要', '400', '万美元', '专利', '战', '赔偿金']},
#  {'doc_title': ['谷歌',
#    'Nexus7',
#    '在',
#    'eBay',
#    '被',
#    '加价',
#    '上百',
#    '美元',
#    '英国',
#    '开售']},
#  {'doc_title': ['中国电信', '回应', '最牛', '胶布', '尽快', '更换', '电线杆']},
#  {'doc_title': ['赛门铁克', '反病毒', '软件', '更新', '后', '捣毁', 'Windows', 'XP', '系统']},
#  {'doc_title': ['广东',
#    '惠州',
#    '2015',
#    '年物',
#    '联网',
#    '产业',
#    '产值',
#    '将',
#    '超',
#    '600',
#    '亿元']},
#  {'doc_title': ['京东',
#    '商城',
#    '618',
#    '大促',
#    '获',
#    '双赢',
#    '众',
#    '手机',
#    '品牌',
#    '斩获',
#    '颇丰']},
#  {'doc_title': ['谷歌', '将', '推出', '低价', 'Chrome', '本售', '400', '美元', '内']},
#  {'doc_title': ['江苏省', '互联网', '企', '签署', '共建', '网络', '文明', '自律', '公约']},
#  {'doc_title': ['前', '诺基亚', '员工', '创立', '公司', '开发', 'MeeGo', '新手机']},
#  {'doc_title': ['评论', '中国', '企业家', '的', '赛事', '选择']},
#  {'doc_title': ['思科', '全球', '渠道', '销售', '总裁', '宣布', '换帅']},
#  {'doc_title': ['惠普', '推出', '亚太', '和', '日本', '地区', '融合', '云', '解决方案']},
#  {'doc_title': ['唯恐', '苹果', '主导', '行业', '智能', '电视', '制造商', '结成联盟']},
#  {'doc_title': ['传',
#    '诺基亚',
#    '将',
#    '重新',
#    '开发',
#    'Meltemi',
#    '并',
#    '推出',
#    '更',
#    '廉价',
#    '智能机']},
#  {'doc_title': ['阿里', '推云', '电商', '平台', '成本', '更', '低']},
#  {'doc_title': ['评论', 'RIM', '或成', '企业', '收购', '目标']},
#  {'doc_title': ['评论', '电商', '屏蔽', '差评', '凸显', '网络', '购物', '信用', '体系', '缺失']},
#  {'doc_title': ['南充', '工商', '暂扣', '30', '部', '走私', '苹果机']},
#  {'doc_title': ['智能机', '后浪', '拍', '前浪', '小米', '手机', '跌落', '性价比', '神坛']},
#  {'doc_title': ['2000',
#    '年',
#    '1',
#    '月',
#    '创办',
#    '易观',
#    '咨询',
#    '公司',
#    '总裁兼',
#    '首席',
#    '顾问']},
#  {'doc_title': ['消息', '称', 'Nexus', '7', '平板', '会', '通过', '零售商', '销售']},
#  {'doc_title': ['微软', '发布', '新一代', 'Office', '预览版']},
#  {'doc_title': ['微软', '将', '旧式', 'Surface', '电脑', '更名', '为', 'PixelSense']},
#  {'doc_title': ['风行', '网', '佘清舟', '融合', '让', '电影', '的', '力量', '更', '强大']},
#  {'doc_title': ['硅谷', '中', '乔布斯', '最', '佩服', '扎克', '伯格']},
# ...
#  {'doc_title': ['苹果',
#    '美国',
#    '零售店',
#    '员工',
#    '称新',
#    'iPhone',
#    '将',
#    '于',
#    '9',
#    '月',
#    '21',
#    '日',
#    '亮相']},
#  {'doc_title': ['逼死', '盛大', '手机', '联想', '4.5', '寸超', '廉价', '机再', '曝光']},
#  {'doc_title': ['深圳', '报业', '集团', '深圳特区', '报', '总编辑', '黄扬略', '照片', '一']},
#  {'doc_title': ['美',
#    '运营商',
#    '拟',
#    '采用',
#    '不',
#    '限时',
#    '长',
#    '通话',
#    '数据',
#    '收入',
#    '占',
#    '比',
#    '攀升']},
#  {'doc_title': ['苹果', '机顶盒', '将', '支持', '第三方', '应用']},
#  {'doc_title': ['谁', '将', '继续', '专注', '于', 'PC', '业务', '不会', '是', '戴尔']},
#  {'doc_title': ['谷歌', '股东', '批准', '拆股', '计划', '确保', '创始人', '控制权']},
#  {'doc_title': ['三星', '申请', '安卓', '桌面图标', '堆叠', '式', '存放', '专利']},
#  {'doc_title': ['传', '戴尔', '收购', 'Quest', '接近', '完成', '总价', '23.2', '亿美元']},
#  {'doc_title': ['应用', '交易', '服务商', 'Apptopia', '获', '100', '万美元', '种子', '融资']},
#  {'doc_title': ['谷歌', '创始人', '病休', '引发', '投资者', '担忧']},
#  {'doc_title': ['苹果', 'APP', 'Store', '四年', '已过', '巅峰', '用户', '关注度', '走低']},
#  {'doc_title': ['科学家', '提出', '外星人', '五大', '假想', '外星人', '不会', '吃', '我们']},
#  {'doc_title': ['关于', '搜狐', 'IT', '博客', '训练营']},
#  {'doc_title': ['英', '男子', '对', '无线', '辐射', '过敏']},
#  {'doc_title': ['视频', '微软', 'Office', '2013', 'DEMO', '操作', '演示']},
#  {'doc_title': ['Spool',
#    '将',
#    '关闭',
#    '网络',
#    '书签',
#    '服务',
#    '团队',
#    '将',
#    '加盟',
#    'Facebook']},
#  {'doc_title': ['奢华', '家居', '品鉴', '欧洲', '现代', '厨房', '设计']},
#  {'doc_title': ['植物', '大战', '僵尸', '现实', '版', '美', '发明', '步枪', '专打', '僵尸']},
#  {'doc_title': ['10', '分钟', '瘦脸', '绝活', '让', '脸', '小', '一圈']},
#  {'doc_title': ['微博晒', '娃', '幸福', '当心', '坏人', '盯上']},
#  {'doc_title': ['涂', '口红', '之前', '一定', '要', '擦', '润唇膏']},
#  {'doc_title': ['消息',
#    '称',
#    '亚马逊',
#    '或',
#    '将',
#    '推出',
#    '至少',
#    '三款',
#    'Kindle',
#    'Fire',
#    '2']},
#  {'doc_title': ['怕',
#    '走光',
#    '的',
#    '刘亦菲',
#    '非得',
#    '把',
#    '原来',
#    '的',
#    '抹胸',
#    '裙',
#    '变成',
#    '吊带裙',
#    '吊带',
#    '挂',
#    '在',
#    '肩上',
#    '显得',
#    '画蛇添足']},
#  {'doc_title': ['电信', '运营', '企业', 'OSS', '系统', '的', '建设', '与', '实施']},
#  {'doc_title': ['绝', '美雪', '纺', '连衣裙', '飘飘', '夏日', '疯狂', '吸睛']},
#  {'doc_title': ['超极本', '售价', '太高', '销售', '暂不佳', '降价', '或迎', '市场', '井喷']},
#  {'doc_title': ['上品', '夏季', '深度', '打折', '季', '让', '你', '省钱', '没商量']},
#  {'doc_title': ['蛟龙',
#    '号',
#    '今日',
#    '7',
#    '时',
#    '结束',
#    '7',
#    '千米',
#    '级',
#    '海试',
#    '首次',
#    '下潜',
#    '试验']},
#  {'doc_title': ['八仙过海', '美女', '塑身']},
#  {'doc_title': ['淘宝', '司法', '拍卖', '回应', '中', '拍协', '拍卖', '主体', '的', '合法']},
#  {'doc_title': ['拳王', '阿里', '将', '代言', 'LV', '并', '推出', '最新', '大片']},
#  {'doc_title': ['北京', 'IPTV', '低调', '测试', '尚未', '推广', '用户', '上线', '测试']},
#  {'doc_title': ['一个',
#    '冬天',
#    '要',
#    '用',
#    '一大',
#    '瓶',
#    '觉得',
#    '手',
#    '脸',
#    '都',
#    '很',
#    '舒服',
#    '也',
#    '没有',
#    '很',
#    '干',
#    '或者',
#    '起',
#    '皮',
#    '后来',
#    '用过']},
#  {'doc_title': ['微软', '称', '放弃', '开始', '按钮', '因', '用户', '使用率', '下滑']},
#  {'doc_title': ['新婚之夜', '女人', '到底', '在', '胡思乱想', '什么']},
#  {'doc_title': ['沃达丰', '16', '亿美元', '购大东', '环球', '一案', '获', '股东大会', '批准']},
#  {'doc_title': ['M',
#    '.',
#    'A',
#    '.',
#    'C',
#    '彩妆',
#    '可以',
#    '实现',
#    '不同',
#    '种族',
#    '不同',
#    '性别',
#    '不同',
#    '年龄',
#    '的',
#    '人',
#    '追逐',
#    '美丽',
#    '的',
#    '梦想']},
#  {'doc_title': ['安徽', '联通', '出新招', '公务员', '1', '元', '随意', '打']},
#  {'doc_title': ['美国', '又现', '丧尸', '女', '裸奔', '街头', '打', '幼子']},
#  {'doc_title': ['深圳', '彩电', '企业', '面临', '多重', '困境']},
#  {'doc_title': ['16', '岁', '少女', '恋上', '大', '15', '岁', '男人', '两次', '堕胎']},
#  {'doc_title': ['广州日报', '基本', '实现', '整体', '上市']},
#  {'doc_title': ['智能手机', '还有', '降价', '空间', '硬件', '最低', '成本', '低于', '400', '元']},
#  {'doc_title': ['欧洲航天局',
#    '了解',
#    '宇航员',
#    '在',
#    '进行',
#    '超',
#    '长距离',
#    '飞行',
#    '任务',
#    '时所',
#    '需要',
#    '做好',
#    '的',
#    '心理',
#    '及',
#    '生理',
#    '准备']},
#  {'doc_title': ['原生',
#    '势力',
#    '大',
#    'Twitter',
#    '第三方',
#    '客户端',
#    '发文',
#    '仅',
#    '占',
#    '23%']},
#  {'doc_title': ['淘宝网', '店主', '猝死', '梦中', '网友', '呼吁', 'IT', '从业者', '关注', '健康']},
#  {'doc_title': ['2010', '年', '中国科协', '年会', '图文', '直播']},
#  {'doc_title': ['广电总局', '称微', '电影', '等', '需先', '审后播', '网站', '表示', '欢迎']},
#  {'doc_title': ['奢侈品', '网购', '那些', '真真假假', '的', '游戏']},
#  {'doc_title': ['消息',
#    '称',
#    '微软',
#    'Surface',
#    '平板',
#    '电脑',
#    '售价',
#    '最低',
#    '599',
#    '美元']},
#  {'doc_title': ['每年', '的', '9', '月', '26', '日', '世界', '避孕', '日']},
#  {'doc_title': ['蜜月', '期间', '婆婆', '18', '次', '打断', '我们', '房事']},
#  {'doc_title': ['很', '给', '力', '夜间', '密集', '保养', '小贴士']},
#  {'doc_title': ['捕鱼', '达', '人', '续集', '将', '发布', '曾', '放弃', '开发', 'PC', '版本']},
#  {'doc_title': ['中国', '城市', '云', '计算', '系列', '现场会', '杭州', '站', '成功', '举办']},
#  {'doc_title': ['北京',
#    '苹果',
#    '最',
#    '被',
#    '贼',
#    '惦记',
#    '仅',
#    '海淀',
#    '每',
#    '3',
#    '天',
#    '丢',
#    '一部']},
#  {'doc_title': ['微软', '发', '新版', 'Office', '对抗', '谷歌', '强化', '移动', '战略']},
#  {'doc_title': ['最好', '的', '礼物', 'Facebook', '的', '婚姻', '态度']},
#  {'doc_title': ['顶星', 'Topstar', '笔记本', '大全']},
#  {'doc_title': ['手机', '电影节', '打造', '跨界', '合作', '新', '平台']},
#  {'doc_title': ['口水仗', '时间表']},
#  {'doc_title': ['搜狐', '手机', '奥运', '观赛', '平台', '搜狐', '奥运', '2012', '上线']},
#  {'doc_title': ['百思买', '宣布', '裁员', '2400', '人', '占', '总', '员工', '1.4%']},
#  {'doc_title': ['TOM',
#    '或失',
#    'Skype',
#    '在',
#    '华',
#    '代理权',
#    '微软',
#    '收购',
#    '后',
#    '想',
#    '整合']},
#  {'doc_title': ['三星', '否认', '计划', '涉足', '类似', 'Facebook', '的', 'SNS', '业务']},
#  {'doc_title': ['西装', '外套', '不能', '少', '夏季', '商务', '急需', '应对']},
#  {'doc_title': ['意大利', 'ELAND', '旗下', '4', '大', '奢侈', '品牌', '落户', '上海']},
#  {'doc_title': ['浪漫', '情人节', '让', '我们', '一', '起来', '化', '化妆', '调', '调情']},
#  {'doc_title': ['猫', '人', '装', '女郎', '2012', '全国', '海选', '起航']},
#  {'doc_title': ['新婚夜', '老公', '房事', '太', '害羞', '我', '干着急']},
#  {'doc_title': ['吴宗宪', '爆', '周杰伦', '刘德华', '因', '歌名', '结仇']},
#  {'doc_title': ['重庆', '男子', '痴迷', '非诚', '勿扰', '精神', '出轨']},
#  {'doc_title': ['富豪', '的', '岛主', '梦', '能', '移动', '的', '豪华', '人工岛']},
#  {'doc_title': ['阴雨连绵', '天', '性生活', '如何', '防潮']},
#  {'doc_title': ['变态', '男友', '送', '我', '一箱', '丝袜', '让', '我', '换', '着', '穿']},
#  {'doc_title': ['迎', '奥运', '英伦', '风', '限量版', '无线电话', '首发']},
#  {'doc_title': ['美国', '调查', '经济', '越', '低迷', '女人', '越', '花钱']},
#  {'doc_title': ['搜狐', '女人', '频道', '生活', '新', '栏目']},
#  {'doc_title': ['泡泡', '袖巧', '遮', '麒麟', '臂', '一秒', '显瘦', '十余斤']},
#  {'doc_title': ['午夜', '性感', '女房东', '把', '我', '骗', '进', '车里', '激情']},
#  {'doc_title': ['女人', '9', '个性', '姿势', '让', '男人', '垂涎欲滴']},
#  {'doc_title': ['美妙', '房事', '有效', '治愈', '男女', '4', '种病']},
#  {'doc_title': ['伦敦', '时装周', '25', '岁', '英气', '正旺', '展露', '锋芒']},
#  {'doc_title': ['知性', '优雅', '沟通', '世界']},
#  {'doc_title': ['3', '分钟', '快速', '韩式', '编发']},
#  {'doc_title': ['编辑', '亲身', '体验', '30', '天', '不', '洗脸', '护肤', '法']},
#  {'doc_title': ['刘德华', '女儿', '取名', 'Hanna', '豪掷', '2', '亿', '购屋']},
#  {'doc_title': ['想要', '嫁', '得', '好', '你', '必须', '要', '分清', '这些', '事']},
#  {'doc_title': ['职场', '新鲜', '人', '的', '锦囊妙计']},
#  {'doc_title': ['刘恺威', '香港', '购', '爱巢', '房产证', '署名', '杨幂']},
#  {'doc_title': ['高考', '体检', '现状', '脱', '与', '不脱', '之间', '的', '迟疑']},
#  {'doc_title': ['李泽楷', '疑有', '新欢', '女方', '依然', '是', '灰姑娘']},
#  {'doc_title': ['性感女', '鞋', 'PELLE', 'MODA', '正式', '登陆', '中国']},
#  {'doc_title': ['给', '虚伪', '无味', '的', '爱情', '一记', '响亮', '的', '耳光']},
#  {'doc_title': ['锋丽', '浪潮', '色彩', '袭', '来']},
#  {'doc_title': ['捷夫', '珠宝', '推出', '全新', '半夏', '花园', '系列']},
#  {'doc_title': ['女人', '创造', '历史']},
#  {'doc_title': ['增强', '电子商务', '基础设施']},
#  {'doc_title': ['海信', '董事长', '周厚健', '断言', '过半', '国产', '电视', '品牌', '将', '淘汰']},
#  {'doc_title': ['ARM', '拟于', '2015', '年', '占据', '笔记本', '芯片', '市场', '20%']},
#  {'doc_title': ['265', '亿', '节能', '惠民', '补贴', '催热', '家电市场']},
#  {'doc_title': ['中国联通', '推出', '年度', '定制', '高端', '双屏', '手机', '三星', '大器', 'II']},
#  {'doc_title': ['报告', '称', '二季度', 'Android', '份额', '51%']},
#  {'doc_title': ['网上商城', '吞噬', '小', '网店', '市场']},
#  {'doc_title': ['Facebook',
#    '接连',
#    '宣布',
#    '新',
#    '业务',
#    '股价',
#    '已',
#    '从',
#    '低位',
#    '反弹',
#    '30%']},
#  {'doc_title': ['苹果',
#    '大会',
#    '将',
#    '开幕',
#    '或',
#    '将',
#    '发布',
#    'iOS',
#    '6',
#    '与',
#    'MacBook',
#    'Pro']},
#  {'doc_title': ['组团', '吃', '垃圾', '只为', '向', '公众', '传递', '节约', '理念']},
#  {'doc_title': ['探秘', '台北', '国际', '电脑', '展', '超极本', '狂潮', '再度', '来袭']},
#  {'doc_title': ['中概',
#    '股',
#    '全线',
#    '下跌',
#    '百度',
#    '跌',
#    '2.84%',
#    '盘后',
#    '公布',
#    'Q2',
#    '财报']},
#  {'doc_title': ['暴雨', '或', '将', '水蒸气', '送入', '平流层', '加速', '臭氧', '流失']},
#  {'doc_title': ['微软', '12', '亿美元', '收购', 'Yammer']},
#  {'doc_title': ['2012', '财富', '世界', '500', '强', '华为', '联想', '再次', '入榜']},
#  {'doc_title': ['网购', '奢侈品', '别信', '香港', '发票']},
#  {'doc_title': ['传言',
#    '又',
#    '起',
#    '消息人士',
#    '称',
#    'iPad',
#    'Mini',
#    '屏幕',
#    '为',
#    '7.85',
#    '英寸']},
#  {'doc_title': ['郭台铭', '死', '磕', '面板', '投资', '夏普亏', '13', '亿']},
#  {'doc_title': ['美丽', '帮帮忙', '西瓜皮', '敷脸', '补水', '又', '增白']},
#  {'doc_title': ['奥运', '致', '伦敦', '房价', '上涨', '女王', '也', '凑热闹']},
#  {'doc_title': ['新娘妆', '教程', '新娘', '晚妆变', '妆', '的', '画法']},
#  {'doc_title': ['Lady', 'Gaga', '首支', '个人', '香水', '问世']},
#  {'doc_title': ['张雨', '绮', '阿娇狂', '追捧', '电光', '蓝', '遮', '赘肉']},
#  {'doc_title': ['孙俪', '桃红', '裙露', '美腿', '熟女', '辣妈', '狂装', '嫩']},
#  {'doc_title': ['八卦', '明星脸', '李小璐', '大婚', '蜜桃', '新娘']},
#  {'doc_title': ['护士', '老婆', '上班时间', '老是', '骗', '我', '回家']},
#  {'doc_title': ['英国', '失业', '男子', '2', '万英镑', '网上', '拍卖', '自己']},
#  {'doc_title': ['姚晨', '撞衫', '苍井空', '女星', '示范', '清凉', '蓝裙']},
#  {'doc_title': ['奥运', '金牌', '与', '金钱', '一起', '创收']},
#  {'doc_title': ['老公', '和', '豪放女', '练', '床技', '我', '守活寡']},
#  {'doc_title': ['柳岩', '拼胸', '又', '露', '腿', '白', '长裙', '穿成', '廉价', '货']},
#  {'doc_title': ['有',
#    '玉兰',
#    '清香',
#    '洗面',
#    '后',
#    '用',
#    '化妆棉',
#    '蘸',
#    '满',
#    '敷',
#    '在',
#    '有',
#    '斑点',
#    '的',
#    '地方',
#    '坚持',
#    '很快',
#    '就',
#    '能',
#    '看到',
#    '效果']},
#  {'doc_title': ['你', '如何', '看待', '乳房', '的', '美']},
#  {'doc_title': ['女人', '十分', '美', '内', '调', '保养', '调出', '肌肤', '好', '气色']},
#  {'doc_title': ['邓超', '周渝民', '彭于', '晏', '帅哥', '扎堆', '看秀']},
#  {'doc_title': ['跟着', '迪斯尼', '公主', '学习', '完美', '爱情', '技巧']},
#  {'doc_title': ['女子', '凌晨', '无', '车位', '按', '喇叭', '泄愤', '车窗', '被', '砸']},
#  {'doc_title': ['美丽', '帮帮忙', '纠正', '15', '个', '毁容', '护肤', '习惯']},
#  {'doc_title': ['英媒', '曝', '梦露', '死时', '或', '怀', '肯尼迪', '孩子']},
#  {'doc_title': ['中国', '广播', '影视网']},
#  {'doc_title': ['霍金', '因希', '格斯', '玻色子', '的', '发现', '而', '输掉', '100', '美元']},
#  {'doc_title': ['日本', '游戏', '公司', 'DeNA', '获得', '变形金刚', '独家代理', '权']},
#  {'doc_title': ['深', '康佳', '获', '授信', '70', '余亿', '否认', '地产', '开发', '提速']},
#  {'doc_title': ['李宁', '等', '14', '个', '服装品牌', '入驻', '苏宁', '易购', '开放平台']},
#  {'doc_title': ['珠宝', '定制', '电商', '戴', '欧妮', '获金', '大福', '2000', '万美元', '投资']},
#  {'doc_title': ['搜狐', '网易', '签约', 'CNTV', '获', '奥运', '视频', '权益']},
#  {'doc_title': ['瘦脸', '其实', '并', '不难', '拍拍', '按', '按', '见', '神效']},
#  {'doc_title': ['展览馆', '设计师', 'Zaha', 'Hadid']},
#  {'doc_title': ['Android',
#    '旗舰',
#    'Google',
#    'Nexus',
#    '从',
#    'Google',
#    'Play',
#    '中',
#    '撤出']},
#  {'doc_title': ['短袖', '衬衫', '连衣裙', '知性', '白领', '轻松', '减龄']},
#  {'doc_title': ['郑希怡', '为应', '采儿', '庆生', '跌落', '三楼', '重伤']},
#  {'doc_title': ['小眼', '短睫', '有救', '实用', '美睫', '化妆', '法']},
#  {'doc_title': ['李若彤', '迷药', '事件']},
#  {'doc_title': ['白衬衣', '太', '单调', '拼接', '样式', '时髦', '最', '吃香']},
#  {'doc_title': ['滨崎步',
#    '发',
#    '类似',
#    '长濑智',
#    '也',
#    '照引',
#    '复合',
#    '传闻',
#    '向',
#    '歌迷',
#    '道歉']},
#  {'doc_title': ['暴利', '女性用品', '排行榜']},
#  {'doc_title': ['族迹', '为', '家族', '而生', '的', '手机', '私密', '社交', '应用']},
#  {'doc_title': ['老公', '想', '我', '变', '开放', '如今', '愁', '我', '太', '性感']},
#  {'doc_title': ['同学', '化身', '三国', '杀', '90', '后', '晒', '另类', '毕业', '照']},
#  {'doc_title': ['腾讯网', '进行', '大', '改版', '重点', '适配', '移动', '互联网']},
#  {'doc_title': ['德国', 'Vallure24K', '黄金', '伏特加', '登陆', '美国']},
#  {'doc_title': ['神九', '待发', '最后', '全区', '合练']},
#  {'doc_title': ['打造', '超', '质感', '雾', '透肌']},
#  {'doc_title': ['Dolce', '&', 'Gabbana', '1985']},
#  {'doc_title': ['2005', '第四届', '中国', '国际', '美容', '时尚']},
#  {'doc_title': ['创维', '全年', '彩电', '销量', '冲刺', '千万', '台']},
#  {'doc_title': ['教', '你', '深度', '美白', '法则']},
#  {'doc_title': ['移动', '互联网', '网让', '生活', '信息', '一手', '掌握']},
#  {'doc_title': ['MELVITA', '有机', '熏衣草', '花水', '赶走', '油光', '持久', '定妆']},
#  {'doc_title': ['天翼', '3G', '网络', '广东', '全省', '行政村', '全', '覆盖']},
#  {'doc_title': ['微软',
#    '反垄断',
#    '纠纷',
#    '将',
#    '了',
#    '要求',
#    '推翻',
#    '欧盟',
#    '9',
#    '亿',
#    '欧元',
#    '罚款']},
#  {'doc_title': ['爱立信', '中国', '有限公司']},
#  {'doc_title': ['10', '29', '07', '55']},
#  {'doc_title': ['际',
#    '通宝',
#    '独立',
#    '商城',
#    '建设',
#    '加代',
#    '运营',
#    '双赢',
#    '战略',
#    '决胜',
#    '网购']},
#  {'doc_title': ['微软', '再诉', '9', '家', '品牌', '电脑', '经销商']},
#  {'doc_title': ['硅谷', '政变', '谷歌', '元老', '迈耶', '意外', '出任', '雅虎', 'CEO']},
#  {'doc_title': ['在', '本次', 'E3', '上', '展出', '的', '最新', 'PC', '游戏', '介绍']},
#  {'doc_title': ['新一代', '互联网协议', 'IPv6', '今日', '正式', '启用']},
#  {'doc_title': ['美',
#    '开发',
#    '出',
#    '一种',
#    '化学',
#    '小',
#    '分子',
#    '或',
#    '可',
#    '用于',
#    '治疗',
#    '失明']},
#  {'doc_title': ['3',
#    '月',
#    '8',
#    '日',
#    '下午',
#    '3',
#    '点',
#    '8',
#    '点',
#    '中友',
#    '1',
#    '层',
#    '珠宝',
#    '东区',
#    '还',
#    '将',
#    '举办',
#    '5',
#    '小时',
#    '的',
#    '4.5',
#    '折',
#    '抢购',
#    '大',
#    '行动']},
#  {'doc_title': ['老公', '的', '手机', '该不该', '看']},
#  {'doc_title': ['苹果', '刚', '申请', '了', '自己', '的', 'Retina', '眼镜', '专利']},
#  {'doc_title': ['2012', '首届', '中国', '针织', '产业', '集群', '年会']},
#  {'doc_title': ['虎', '嗅网', '刘强', '东', '在', '微博上', '还', '卖', '什么']},
#  {'doc_title': ['10', '秒钟', '从', '女人', '的', '外表', '看', '她', '性欲', '强弱']},
#  {'doc_title': ['再婚',
#    '生活',
#    '是',
#    '一个',
#    '再',
#    '学习',
#    '的',
#    '过程',
#    '它',
#    '不会',
#    '让',
#    '人',
#    '感到',
#    '事事',
#    '顺心',
#    '它',
#    '要',
#    '经受考验']},
#  {'doc_title': ['凯瑟琳', '毕', '格罗', '大走', '阳刚', '路线']},
#  {'doc_title': ['日本',
#    '最',
#    '流行',
#    '健康',
#    '减肥',
#    '方法',
#    '30',
#    '天',
#    '轻松',
#    '甩掉',
#    '7',
#    '斤',
#    '肉']},
#  {'doc_title': ['中', '电信', '在', '韩国', '设立', '分公司', '服务', '当地', '中国', '企业']},
#  {'doc_title': ['世界', '奢侈品', '协会', '被', '指', '皮包公司']},
#  {'doc_title': ['天翼', '创投', '开启', '第二轮', '项目', '甄选', '实施', '员工', '持股']},
#  {'doc_title': ['屈臣氏', '优', '大奖', '第三期', '今夏', '清新', '妆容']},
#  {'doc_title': ['红', '歌会', '地道', '北京', '味儿', '打动', '评委', '月光宝盒', '顺利', '晋级']},
#  {'doc_title': ['孙艺', '民间', '金融', '将', '走', '阳光', '路线']},
#  {'doc_title': ['不满', '网恋', '女友', '提', '分手', '男子', '借', '聊天记录', '敲诈']},
#  {'doc_title': ['RedHat', '一财季', '净利', '3750', '万美元', '同比', '增长', '15%']},
#  {'doc_title': ['非常', '绑匪', '受', '关注', '虽', '是', '绑架', '也', '客气']},
#  {'doc_title': ['据', '曝称', '丹佛', '枪击案', '疑犯', '穿', '蝙蝠侠', '电影', '角色', '戏服']},
#  {'doc_title': ['诺基亚', '回应', '债券', '评级', '下调', '声称', '影响', '有限']},
#  {'doc_title': ['简爱', '拜访', '理查', '三世', '袁泉', '王洛勇', '即兴', '试演']},
#  {'doc_title': ['奇虎', '360', '用户', '特供', '手机', '引三大', '质疑']},
#  {'doc_title': ['小灵通', '仍存', '1499', '万', '用户', '自觉', '退网', '可能性', '小']},
#  {'doc_title': ['微软',
#    '去年',
#    '在',
#    '美',
#    '广告',
#    '开支',
#    '超',
#    '10',
#    '亿美元',
#    '位居',
#    '榜首']},
#  {'doc_title': ['招行', '行长', '马蔚华', '手机', '取代', '信用卡', '是', '迟早', '的', '事']},
#  {'doc_title': ['数据',
#    '显示',
#    'Pinterest',
#    '推荐',
#    '流量',
#    '已',
#    '超谷歌',
#    '与',
#    'Twitter']},
#  {'doc_title': ['苹果公司',
#    '有',
#    '多',
#    '牛',
#    'X',
#    '看看',
#    '辞职',
#    '员工',
#    '都',
#    '干',
#    '了',
#    '什么']},
#  {'doc_title': ['IBTEC', '大赛', '花絮']},
#  {'doc_title': ['谷歌', '智能', '眼镜', '能', '上网', '拍照', '打电话']},
#  {'doc_title': ['荒野', '求生', '可借', '自身', '尿液', '生火']},
#  {'doc_title': ['视频', '网站', '广告费', '借', '欧洲杯', '一路', '看涨', '平均', '涨幅', '30%']},
#  {'doc_title': ['完美', '世界', '竺琦', '中国', '网游', '要', '学会', '抱团', '出口']},
#  {'doc_title': ['消息',
#    '称',
#    '苹果',
#    '将',
#    '强制',
#    'iOS',
#    '应用',
#    '开发者',
#    '使用',
#    '高清',
#    '图标']},
#  {'doc_title': ['解读', '基因', '密码', '为什么', '顺产', '的', '孩子', '免疫力', '更强']},
#  {'doc_title': ['飞常准', 'CEO', '郑', '洪峰', '被', '携程', '收购', '不真', '也', '不假']},
#  {'doc_title': ['出口', '东盟', '电子产品', '货值', '增', '五成']},
#  {'doc_title': ['联想', '手机', '专题']},
#  {'doc_title': ['CNTV', '分销', '转播权', '引发', '竞争', '升级']},
#  {'doc_title': ['中国移动', '与', '苹果', '未来', '合作', '或', '直接', '从', '4G', '开始']},
#  {'doc_title': ['评论',
#    'Windows',
#    'Phone',
#    '8',
#    '意义',
#    '重大',
#    '但',
#    '仍',
#    '缺乏',
#    '亮点']},
#  ...]
